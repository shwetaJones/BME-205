# %% [markdown]
# # File Name: Jones_Shweta_problem11.ipynb
# #### Description:
# The program is given an input file the length of the kmer and a sequence. The code outputs the deBrujin graph for that sequence.
# #### Sample CommandLine Entry:
# python Jones_Shweta_problem11.py
# ##### stdin:
# txt file containing a kmer length and sequence
# ##### stdout:
# the deBrujin Graph for the sequence is outputted
# #### Author:
# Shweta Jones
# #### Group:
# Sahasra Shankar, Kritin Nandish, Maheep Luthra
# #### History:
# sj 08/20/2021 Created
# sj 08/21/2021 Updated
# sj 08/25/2021 Updated

# %%
class problemEleven():
    """ Description: The class outputs the deBruijn graph from a sequence """
    """ Input: The input is the length of the kmer and the sequence """
    """ Output: Returns the deBruijn graph """
    def __init__(self, kmerLength, sequence):
        """ Description: The method initializes variables for the class methods """
        """ Input: The input is the kmerlength and sequence """
        """ Output: No output, but these values are initialized """
        self.kmerLength = int(kmerLength)-1 #Saves the length as self
        self.sequence = sequence #Saves sequence as self
        self.totalLength = len(sequence) #Saves the total length of the sequence as self

    def kmerList(self):
        """ Description: The methods creates a list of kmers """
        """ Input: No input, but uses initializes certain values """
        """ Output: The methods returns a list of kmers """
        kmerList = []
        for i in range(int(self.totalLength) - (self.kmerLength) + 1): #Iterates from beginning to end-kmerlength
            kmerList.append(self.sequence[i:i + (self.kmerLength)]) #Adds kmer to list
        return kmerList #Returns a list of kmers

    def kmerDict(self, kmerList):
        """ Description: The method creates a kmer dictionary using the sequences """
        """ Input: There is no input, but it does use a list of sequences """
        """ Output: It returns a dictionary of kmers """
        kmerDict = {}
        for i in range(len(kmerList)): #Creates a dictionary with empty values
            kmerDict[kmerList[i]] = []
        for i in range(len(kmerList)): #Creates dictionary with corresponding kmers
            if (i+1) < len(kmerList): 
                next = kmerList[i+1] #Saves the next kmer
                kmerDict[kmerList[i]].append(next) #Adds to the kmer to the dictionary
        return kmerDict #Returns a dictionary of kmers

def main(inFile):
    """ Description: The class outputs the deBruijn graph from a sequence """
    """ Input: The input is the length of the kmer and the sequence """
    """ Output: Returns the deBruijn graph """
    with open(inFile, "r") as file:
        length = file.readline().rstrip() #Removes unnecessary characters
        sequence = file.readline().rstrip() #Removes unnecessary characters
    processed = problemEleven(length, sequence) #Initializes the variables
    kmerList = processed.kmerList() #Creates the kmerList
    kmerDict = processed.kmerDict(kmerList) #Creates the kmerDictionary
    for i in sorted(kmerDict): #Sorts the dictionary
        if kmerDict[i] != []: #Prints only when there are values
            print(i + ' -> ' + ','.join(kmerDict[i])) #Prints out the dictionary in the expected manner

if __name__== "__main__":
    main("rosalind_ba3d.txt")
# Out:
# AAAAAAGTCTA -> AAAAAGTCTAA
# AAAAAGTCTAA -> AAAAGTCTAAG
# AAAACAACCCA -> AAACAACCCAA
# AAAACCATGGT -> AAACCATGGTT
# AAAACGGGCCT -> AAACGGGCCTA
# AAAAGTCTAAG -> AAAGTCTAAGG
# AAAATACTGCT -> AAATACTGCTC
# AAAATATGGGG -> AAATATGGGGC
# AAACAACCCAA -> AACAACCCAAT
# AAACAGTCGTT -> AACAGTCGTTT
# AAACCAACGCG -> AACCAACGCGT
# AAACCATGGTT -> AACCATGGTTG
# AAACCCCCCTC -> AACCCCCCTCA
# AAACCTCTGAT -> AACCTCTGATC
# AAACGCCAACC -> AACGCCAACCG
# AAACGGGCCTA -> AACGGGCCTAC
# AAAGATTAACA -> AAGATTAACAA
# AAAGGTCATCA -> AAGGTCATCAG
# AAAGTCTAAGG -> AAGTCTAAGGA
# AAAGTTAAGGC -> AAGTTAAGGCC
# AAAGTTCGGGA -> AAGTTCGGGAA
# AAATAACAGCA -> AATAACAGCAA
# AAATACACATG -> AATACACATGG
# AAATACATGGT -> AATACATGGTA
# AAATACGCATC -> AATACGCATCT
# AAATACTGCTC -> AATACTGCTCG
# AAATAGGTTTA -> AATAGGTTTAC
# AAATATGGGGC -> AATATGGGGCA
# AAATCCAATGT -> AATCCAATGTA
# AAATGGCTTCG -> AATGGCTTCGC
# AAATTTGGCGC -> AATTTGGCGCT
# AACAAAATACT -> ACAAAATACTG
# AACAACCCAAT -> ACAACCCAATC
# AACACAGTGGT -> ACACAGTGGTA
# AACACTATGAG -> ACACTATGAGT
# AACACTCTTAT -> ACACTCTTATA
# AACAGCAATGA -> ACAGCAATGAC
# AACAGTAACCC -> ACAGTAACCCT
# AACAGTCGTTT -> ACAGTCGTTTA
# AACATCATTCG -> ACATCATTCGG
# AACATCTATGC -> ACATCTATGCA
# AACCAACGCGT -> ACCAACGCGTA
# AACCATGGTTG -> ACCATGGTTGG
# AACCCAATCAT -> ACCCAATCATG
# AACCCCCCTCA -> ACCCCCCTCAT
# AACCCGCGCCG -> ACCCGCGCCGG
# AACCCTGTGCG -> ACCCTGTGCGG
# AACCGGCTATA -> ACCGGCTATAT
# AACCGTTCCCT -> ACCGTTCCCTG
# AACCGTTCTGC -> ACCGTTCTGCC
# AACCTCTGATC -> ACCTCTGATCG
# AACCTCTGCTG -> ACCTCTGCTGA
# AACCTGTAACG -> ACCTGTAACGA
# AACGAGACAGT -> ACGAGACAGTC
# AACGCCAACCG -> ACGCCAACCGT
# AACGCGTAAAT -> ACGCGTAAATA
# AACGGCGTCCC -> ACGGCGTCCCT
# AACGGGCCTAC -> ACGGGCCTACA
# AACGTAATTCT -> ACGTAATTCTC
# AACTAAGGATT -> ACTAAGGATTG
# AACTACCCGAT -> ACTACCCGATC
# AACTGACGTCG -> ACTGACGTCGG
# AACTGGCGAGG -> ACTGGCGAGGC
# AACTTGGCCTC -> ACTTGGCCTCA
# AAGAACACTAT -> AGAACACTATG
# AAGACAAATAG -> AGACAAATAGG
# AAGACAAGTCC -> AGACAAGTCCA
# AAGACTGATCT -> AGACTGATCTG
# AAGAGCCGCTT -> AGAGCCGCTTG
# AAGATAATGAT -> AGATAATGATT
# AAGATCAATCA -> AGATCAATCAA
# AAGATTAACAA -> AGATTAACAAA
# AAGCCTGCTAG -> AGCCTGCTAGG
# AAGCGAATAGC -> AGCGAATAGCA
# AAGGAGTGAGA -> AGGAGTGAGAT
# AAGGATCGAGC -> AGGATCGAGCA
# AAGGATTGTTT -> AGGATTGTTTC
# AAGGCAACTTG -> AGGCAACTTGG
# AAGGCCCCCTC -> AGGCCCCCTCA
# AAGGCCCGTAC -> AGGCCCGTACC
# AAGGCGGCAAT -> AGGCGGCAATG
# AAGGCTCAGAA -> AGGCTCAGAAT
# AAGGGATTCCG -> AGGGATTCCGC
# AAGGGCTGATG -> AGGGCTGATGT
# AAGGTATAACC -> AGGTATAACCG
# AAGGTCATCAG -> AGGTCATCAGG
# AAGTATACATA -> AGTATACATAT
# AAGTCCACTAA -> AGTCCACTAAA
# AAGTCCACTCA -> AGTCCACTCAA
# AAGTCGTTTTG -> AGTCGTTTTGG
# AAGTCTAAGGA -> AGTCTAAGGAG
# AAGTGTTGTTC -> AGTGTTGTTCT
# AAGTGTTTAGA -> AGTGTTTAGAC
# AAGTTAAGGCC -> AGTTAAGGCCC
# AAGTTCGGGAA -> AGTTCGGGAAC
# AATAACAGCAA -> ATAACAGCAAT
# AATACACATGG -> ATACACATGGC
# AATACATGGTA -> ATACATGGTAC
# AATACGCATCT -> ATACGCATCTC
# AATACTGCTCG -> ATACTGCTCGT
# AATAGACCGTA -> ATAGACCGTAC
# AATAGCACCGG -> ATAGCACCGGT
# AATAGCGAGTT -> ATAGCGAGTTG
# AATAGGTTTAC -> ATAGGTTTACA
# AATATAACGGC -> ATATAACGGCG
# AATATCTCCGA -> ATATCTCCGAT
# AATATGCCCGC -> ATATGCCCGCA
# AATATGCTTTG -> ATATGCTTTGT
# AATATGGGGCA -> ATATGGGGCAC
# AATCAAATCCA -> ATCAAATCCAA
# AATCAAGGCAA -> ATCAAGGCAAC
# AATCATGCTGG -> ATCATGCTGGG
# AATCATTATGA -> ATCATTATGAC
# AATCATTCCGC -> ATCATTCCGCC
# AATCCAATGTA -> ATCCAATGTAG
# AATCCATATTG -> ATCCATATTGC
# AATCCTCGAAG -> ATCCTCGAAGT
# AATCTGGTTAA -> ATCTGGTTAAA
# AATGACGGTGT -> ATGACGGTGTT
# AATGATTAGTT -> ATGATTAGTTG
# AATGCGGCTTT -> ATGCGGCTTTG
# AATGCTAGGAC -> ATGCTAGGACC
# AATGGCTATCA -> ATGGCTATCAC
# AATGGCTTCGC -> ATGGCTTCGCG
# AATGTACAAGG -> ATGTACAAGGT
# AATGTAGAGCG -> ATGTAGAGCGC
# AATGTGAACCG -> ATGTGAACCGG
# AATGTGTCTAA -> ATGTGTCTAAA
# AATTCACACAC -> ATTCACACACG
# AATTCTCTTCG -> ATTCTCTTCGA
# AATTGCCAGGA -> ATTGCCAGGAT
# AATTGTATCGG -> ATTGTATCGGC
# AATTTGGCGCT -> ATTTGGCGCTA
# AATTTTCAAGC -> ATTTTCAAGCC
# ACAAAATACTG -> CAAAATACTGC
# ACAAAATATGG -> CAAAATATGGG
# ACAAAGATTAA -> CAAAGATTAAC
# ACAAATAGGTT -> CAAATAGGTTT
# ACAACAGTAAC -> CAACAGTAACC
# ACAACCCAATC -> CAACCCAATCA
# ACAAGACAAGT -> CAAGACAAGTC
# ACAAGGCGGCA -> CAAGGCGGCAA
# ACAAGGTATAA -> CAAGGTATAAC
# ACAAGTCCACT -> CAAGTCCACTC
# ACAATAGCGAG -> CAATAGCGAGT
# ACAATGTGTCT -> CAATGTGTCTA
# ACACACGTTCC -> CACACGTTCCT
# ACACAGTGGTA -> CACAGTGGTAG
# ACACATGGCGG -> CACATGGCGGG
# ACACCAGTACA -> CACCAGTACAT
# ACACCGATGCC -> CACCGATGCCT
# ACACCTAATCT -> CACCTAATCTG
# ACACCTGTAGG -> CACCTGTAGGC
# ACACGTTCCTA -> CACGTTCCTAG
# ACACTATGAGT -> CACTATGAGTT
# ACACTCAGAGT -> CACTCAGAGTA
# ACACTCGCCGT -> CACTCGCCGTG
# ACACTCTTATA -> CACTCTTATAA
# ACAGAATCATT -> CAGAATCATTC
# ACAGACTGTGC -> CAGACTGTGCT
# ACAGCAATGAC -> CAGCAATGACG
# ACAGCACAATG -> CAGCACAATGT
# ACAGCGATTTA -> CAGCGATTTAG
# ACAGTAACCCT -> CAGTAACCCTG
# ACAGTCATTAA -> CAGTCATTAAT
# ACAGTCGACAT -> CAGTCGACATC
# ACAGTCGTTTA -> CAGTCGTTTAC
# ACAGTGGTAGA -> CAGTGGTAGAC
# ACATATTCGCA -> CATATTCGCAC
# ACATCAAATTT -> CATCAAATTTG
# ACATCATTCGG -> CATCATTCGGT
# ACATCGCGGAG -> CATCGCGGAGT
# ACATCGGCTCT -> CATCGGCTCTC
# ACATCTATGCA -> CATCTATGCAA
# ACATGGCGGGT -> CATGGCGGGTT
# ACATGGTACAC -> CATGGTACACC
# ACCAACATCAT -> CCAACATCATT
# ACCAACGCGTA -> CCAACGCGTAA
# ACCACAGCACA -> CCACAGCACAA
# ACCACGAGAGA -> CCACGAGAGAA
# ACCAGTACATC -> CCAGTACATCG
# ACCATGCGTAC -> CCATGCGTACC
# ACCATGGTTGG -> CCATGGTTGGG
# ACCCAATCATG -> CCCAATCATGC
# ACCCCAGTGGT -> CCCCAGTGGTG
# ACCCCCCTCAT -> CCCCCCTCATG
# ACCCCGCTAAT -> CCCCGCTAATA
# ACCCCTCGCGA -> CCCCTCGCGAA
# ACCCGATCACC -> CCCGATCACCG
# ACCCGCGCCGG -> CCCGCGCCGGA
# ACCCGTATAAT -> CCCGTATAATT
# ACCCTGTGCGG -> CCCTGTGCGGG
# ACCGATGCCTG -> CCGATGCCTGT
# ACCGATTACGT -> CCGATTACGTC
# ACCGCCGGAAG -> CCGCCGGAAGA
# ACCGCTTTCAT -> CCGCTTTCATG
# ACCGGCTATAT -> CCGGCTATATA
# ACCGGGAATCC -> CCGGGAATCCA
# ACCGGGGCGCT -> CCGGGGCGCTG
# ACCGGTTACCC -> CCGGTTACCCG
# ACCGTACTCAG -> CCGTACTCAGG
# ACCGTTCCCTG -> CCGTTCCCTGG
# ACCGTTCTGCC -> CCGTTCTGCCG
# ACCTAATCTGG -> CCTAATCTGGT
# ACCTAGAAGTA -> CCTAGAAGTAT
# ACCTAGAGGAC -> CCTAGAGGACT
# ACCTCTGATCG -> CCTCTGATCGG
# ACCTCTGCTGA -> CCTCTGCTGAG
# ACCTGATCTGT -> CCTGATCTGTG
# ACCTGTAACGA -> CCTGTAACGAG
# ACCTGTAGGCG -> CCTGTAGGCGT
# ACGAATATGCT -> CGAATATGCTT
# ACGACAAGGCG -> CGACAAGGCGG
# ACGAGACAGTC -> CGAGACAGTCG
# ACGAGAGAAGG -> CGAGAGAAGGG
# ACGAGGGGTCT -> CGAGGGGTCTA
# ACGATCGAAAA -> CGATCGAAAAC
# ACGATTTTGAG -> CGATTTTGAGG
# ACGCATCTCGA -> CGCATCTCGAT
# ACGCCAACCGT -> CGCCAACCGTT
# ACGCGTAAATA -> CGCGTAAATAC
# ACGGCCCTCAA -> CGGCCCTCAAA
# ACGGCGTCCCT -> CGGCGTCCCTG
# ACGGGCCTACA -> CGGGCCTACAC
# ACGGTGTTAAC -> CGGTGTTAACA
# ACGTAATTCTC -> CGTAATTCTCT
# ACGTCACTCAC -> CGTCACTCACC
# ACGTCGGTCCA -> CGTCGGTCCAC
# ACGTGATGCAT -> CGTGATGCATC
# ACGTTCCTAGT -> CGTTCCTAGTG
# ACTAAAACGGG -> CTAAAACGGGC
# ACTAACCCGCG -> CTAACCCGCGC
# ACTAACTGGCG -> CTAACTGGCGA
# ACTAAGGATTG -> CTAAGGATTGT
# ACTACCAACAT -> CTACCAACATC
# ACTACCCGATC -> CTACCCGATCA
# ACTAGTCCGAC -> CTAGTCCGACC
# ACTATCCCCGA -> CTATCCCCGAA
# ACTATGAGTTA -> CTATGAGTTAT
# ACTCAAAGGTC -> CTCAAAGGTCA
# ACTCACCTAGA -> CTCACCTAGAG
# ACTCAGAGTAT -> CTCAGAGTATT
# ACTCAGGATCG -> CTCAGGATCGC
# ACTCATATTAA -> CTCATATTAAT
# ACTCCGATGAG -> CTCCGATGAGG
# ACTCGCCGTGC -> CTCGCCGTGCC
# ACTCGGCAAAT -> CTCGGCAAATA
# ACTCGTGTCGC -> CTCGTGTCGCA
# ACTCTTATAAT -> CTCTTATAATG
# ACTCTTGGCGC -> CTCTTGGCGCA
# ACTGACCACGA -> CTGACCACGAG
# ACTGACGTCGG -> CTGACGTCGGT
# ACTGATCTGTT -> CTGATCTGTTT
# ACTGCTCGTCA -> CTGCTCGTCAG
# ACTGGCGAGGC -> CTGGCGAGGCA
# ACTGTAAAACA -> CTGTAAAACAA
# ACTGTGCTCCC -> CTGTGCTCCCT
# ACTTGGCCTCA -> CTTGGCCTCAC
# AGAACACTATG -> GAACACTATGA
# AGAAGCGAATA -> GAAGCGAATAG
# AGAAGGGATTC -> GAAGGGATTCC
# AGAAGTATACA -> GAAGTATACAT
# AGAAGTCGTTT -> GAAGTCGTTTT
# AGAATCATTCC -> GAATCATTCCG
# AGAATGCGGCT -> GAATGCGGCTT
# AGACAAATAGG -> GACAAATAGGT
# AGACAAGTCCA -> GACAAGTCCAC
# AGACACCTAAT -> GACACCTAATC
# AGACAGTCATT -> GACAGTCATTA
# AGACAGTCGAC -> GACAGTCGACA
# AGACCGCTTTC -> GACCGCTTTCA
# AGACCGTACTC -> GACCGTACTCA
# AGACGAGGGGT -> GACGAGGGGTC
# AGACTCATATT -> GACTCATATTA
# AGACTGATCTG -> GACTGATCTGT
# AGACTGTGCTC -> GACTGTGCTCC
# AGAGAAGGGAT -> GAGAAGGGATT
# AGAGACAGTCA -> GAGACAGTCAT
# AGAGCCGCTTG -> GAGCCGCTTGT
# AGAGCGCCAAT -> GAGCGCCAATG
# AGAGCGTGAGA -> GAGCGTGAGAC
# AGAGGAATATC -> GAGGAATATCT
# AGAGGACTCCG -> GAGGACTCCGA
# AGAGGGCTTGG -> GAGGGCTTGGT
# AGAGTATTACC -> GAGTATTACCT
# AGATAATGATT -> GATAATGATTA
# AGATCAATCAA -> GATCAATCAAG
# AGATCCTTATA -> GATCCTTATAC
# AGATTAACAAA -> GATTAACAAAA
# AGCAATGACGG -> GCAATGACGGT
# AGCACAAGACA -> GCACAAGACAA
# AGCACAATGTG -> GCACAATGTGT
# AGCACCGGTTA -> GCACCGGTTAC
# AGCCGCTTGTG -> GCCGCTTGTGC
# AGCCTGCTAGG -> GCCTGCTAGGA
# AGCGAATAGCA -> GCGAATAGCAC
# AGCGAGTTGTT -> GCGAGTTGTTG
# AGCGATTTAGA -> GCGATTTAGAG
# AGCGCAAGATC -> GCGCAAGATCA
# AGCGCCAATGT -> GCGCCAATGTG
# AGCGTGAGACA -> GCGTGAGACAC
# AGCTATGCCGC -> GCTATGCCGCG
# AGGAATATCTC -> GGAATATCTCC
# AGGACAAAGAT -> GGACAAAGATT
# AGGACCCCAGT -> GGACCCCAGTG
# AGGACTCCGAT -> GGACTCCGATG
# AGGAGGCAGTC -> GGAGGCAGTCG
# AGGAGGGCCAC -> GGAGGGCCACT
# AGGAGTGAGAT -> GGAGTGAGATC
# AGGATCGAGCA -> GGATCGAGCAC
# AGGATCGCCAA -> GGATCGCCAAT
# AGGATTCAAGA -> GGATTCAAGAG
# AGGATTGTTTC -> GGATTGTTTCA
# AGGATTTTCTA -> GGATTTTCTAG
# AGGCAACTTGG -> GGCAACTTGGC
# AGGCAATTTTC -> GGCAATTTTCA
# AGGCACGTGAT -> GGCACGTGATG
# AGGCAGAGCGT -> GGCAGAGCGTG
# AGGCAGAGGAA -> GGCAGAGGAAT
# AGGCAGTCGTT -> GGCAGTCGTTA
# AGGCCCCCTCA -> GGCCCCCTCAA
# AGGCCCGTACC -> GGCCCGTACCG
# AGGCCTCTTTA -> GGCCTCTTTAC
# AGGCGGCAATG -> GGCGGCAATGC
# AGGCGTATTAG -> GGCGTATTAGG
# AGGCTAAGAAC -> GGCTAAGAACA
# AGGCTAGTGAC -> GGCTAGTGACC
# AGGCTATTCCA -> GGCTATTCCAT
# AGGCTCAGAAT -> GGCTCAGAATG
# AGGCTCGTGGT -> GGCTCGTGGTT
# AGGGATTCCGC -> GGGATTCCGCC
# AGGGCCACTAA -> GGGCCACTAAC
# AGGGCTGATGT -> GGGCTGATGTC
# AGGGCTTGGTC -> GGGCTTGGTCT,GGGCTTGGTCC
# AGGGGTCTACC -> GGGGTCTACCC
# AGGTAGTTGGG -> GGTAGTTGGGG
# AGGTATAACCG -> GGTATAACCGT
# AGGTCATCAGG -> GGTCATCAGGC
# AGGTTTACATC -> GGTTTACATCA
# AGTAACCCTGT -> GTAACCCTGTG
# AGTACATCGCG -> GTACATCGCGG
# AGTAGTGTATC -> GTAGTGTATCG
# AGTATACATAT -> GTATACATATT
# AGTATTACCTA -> GTATTACCTAG
# AGTCAGGTAGT -> GTCAGGTAGTT
# AGTCATTAATC -> GTCATTAATCA
# AGTCCACTAAA -> GTCCACTAAAA
# AGTCCACTCAA -> GTCCACTCAAA
# AGTCCGACCAT -> GTCCGACCATG
# AGTCGACATCG -> GTCGACATCGG
# AGTCGTTACTA -> GTCGTTACTAT
# AGTCGTTTACA -> GTCGTTTACAC
# AGTCGTTTTGG -> GTCGTTTTGGG
# AGTCTAAGGAG -> GTCTAAGGAGT
# AGTCTTATTAC -> GTCTTATTACT
# AGTGAAACCTC -> GTGAAACCTCT
# AGTGACCGGGA -> GTGACCGGGAA
# AGTGAGATCCT -> GTGAGATCCTT
# AGTGGTAGACT -> GTGGTAGACTC
# AGTGGTGCAAC -> GTGGTGCAACT
# AGTGTATCGCT -> GTGTATCGCTC
# AGTGTGCCGCG -> GTGTGCCGCGC
# AGTGTGTAACT -> GTGTGTAACTG
# AGTGTTGTTCT -> GTGTTGTTCTG
# AGTGTTTAGAC -> GTGTTTAGACG
# AGTTAAGGCCC -> GTTAAGGCCCC
# AGTTATCAGAC -> GTTATCAGACC
# AGTTATCGTGC -> GTTATCGTGCC
# AGTTCGGGAAC -> GTTCGGGAACC
# AGTTGAAATAC -> GTTGAAATACA
# AGTTGCATTAA -> GTTGCATTAAT
# AGTTGGGGGCG -> GTTGGGGGCGG
# AGTTGTTGGCC -> GTTGTTGGCCT
# ATAAATGGCTT -> TAAATGGCTTC
# ATAACAGCAAT -> TAACAGCAATG
# ATAACCGTTCT -> TAACCGTTCTG
# ATAACGGCGTC -> TAACGGCGTCC
# ATAATATAACG -> TAATATAACGG
# ATAATGATTAG -> TAATGATTAGT
# ATAATGTACAA -> TAATGTACAAG
# ATAATTCACAC -> TAATTCACACA
# ATACACATGGC -> TACACATGGCG
# ATACATATTCG -> TACATATTCGC
# ATACATGGTAC -> TACATGGTACA
# ATACGAATATG -> TACGAATATGC
# ATACGCATCTC -> TACGCATCTCG
# ATACTGACCAC -> TACTGACCACG
# ATACTGCTCGT -> TACTGCTCGTC
# ATAGACCGTAC -> TAGACCGTACT
# ATAGCACCGGT -> TAGCACCGGTT
# ATAGCGAGTTG -> TAGCGAGTTGT
# ATAGGTTTACA -> TAGGTTTACAT
# ATAGTCAGGTA -> TAGTCAGGTAG
# ATATAACGGCG -> TATAACGGCGT
# ATATAATATAA -> TATAATATAAC
# ATATCTCCGAT -> TATCTCCGATT
# ATATGCCCGCA -> TATGCCCGCAG
# ATATGCTTTGT -> TATGCTTTGTC
# ATATGGGGCAC -> TATGGGGCACA
# ATATGTTATGT -> TATGTTATGTG
# ATATTAATGGC -> TATTAATGGCT
# ATATTCGCACA -> TATTCGCACAC
# ATATTGCCCCC -> TATTGCCCCCG
# ATATTTCTCCG -> TATTTCTCCGA
# ATCAAATCCAA -> TCAAATCCAAT
# ATCAAATTTGG -> TCAAATTTGGC
# ATCAAGGCAAC -> TCAAGGCAACT
# ATCAAGGCCCG -> TCAAGGCCCGT
# ATCAAGTCCAC -> TCAAGTCCACT
# ATCAATCAAGG -> TCAATCAAGGC
# ATCACAATAGC -> TCACAATAGCG
# ATCACCGCCGG -> TCACCGCCGGA
# ATCAGACCGCT -> TCAGACCGCTT
# ATCAGAGGGCT -> TCAGAGGGCTT
# ATCAGGCTAAG -> TCAGGCTAAGA
# ATCAGTCTTAT -> TCAGTCTTATT
# ATCATCAGTCT -> TCATCAGTCTT
# ATCATGATTAT -> TCATGATTATT
# ATCATGCTGGG -> TCATGCTGGGG
# ATCATTATGAC -> TCATTATGACT
# ATCATTCCGCC -> TCATTCCGCCA
# ATCATTCGGTT -> TCATTCGGTTC
# ATCCAATGTAG -> TCCAATGTAGA
# ATCCATATTGC -> TCCATATTGCC
# ATCCCCGAAAC -> TCCCCGAAACA
# ATCCTCGAAGT -> TCCTCGAAGTG
# ATCCTTATACG -> TCCTTATACGA
# ATCGAAAACCA -> TCGAAAACCAT
# ATCGAGCACAA -> TCGAGCACAAG
# ATCGAGGCCTC -> TCGAGGCCTCT
# ATCGCCAATCA -> TCGCCAATCAT
# ATCGCCGCTAT -> TCGCCGCTATC
# ATCGCGGAGTG -> TCGCGGAGTGT
# ATCGCTCGGTA -> TCGCTCGGTAA
# ATCGGATCGCC -> TCGGATCGCCG
# ATCGGCAGGAT -> TCGGCAGGATT
# ATCGGCTCTCC -> TCGGCTCTCCG
# ATCGTGCCTTG -> TCGTGCCTTGG
# ATCTATGCAAG -> TCTATGCAAGA
# ATCTCCGATTA -> TCTCCGATTAG
# ATCTCGATCTT -> TCTCGATCTTA
# ATCTGGTTAAA -> TCTGGTTAAAG
# ATCTGTGCCCT -> TCTGTGCCCTA
# ATCTGTTTGTT -> TCTGTTTGTTG
# ATCTTATCGAG -> TCTTATCGAGG
# ATGACGGTGTT -> TGACGGTGTTA
# ATGACTGTAAA -> TGACTGTAAAA
# ATGAGGCTAGT -> TGAGGCTAGTG
# ATGAGTTATCA -> TGAGTTATCAG
# ATGATTAGTTG -> TGATTAGTTGC
# ATGATTATTCC -> TGATTATTCCA
# ATGCAAGACTG -> TGCAAGACTGA
# ATGCATCAGAG -> TGCATCAGAGG
# ATGCCCGCAGG -> TGCCCGCAGGC
# ATGCCGCGATA -> TGCCGCGATAA
# ATGCCTGTGGC -> TGCCTGTGGCT
# ATGCGGCTTTG -> TGCGGCTTTGC
# ATGCGTACCTG -> TGCGTACCTGA
# ATGCTAGGACC -> TGCTAGGACCC
# ATGCTGGGGCA -> TGCTGGGGCAA
# ATGCTTTGTCC -> TGCTTTGTCCG
# ATGGATCAAGG -> TGGATCAAGGC
# ATGGCAAGATA -> TGGCAAGATAA
# ATGGCGGGTTG -> TGGCGGGTTGA
# ATGGCTATCAC -> TGGCTATCACA
# ATGGCTTCGCG -> TGGCTTCGCGC
# ATGGGGCACAA -> TGGGGCACAAC
# ATGGTACACCG -> TGGTACACCGA
# ATGGTTGGGCC -> TGGTTGGGCCA
# ATGGTTTCACT -> TGGTTTCACTC
# ATGTACAAGGT -> TGTACAAGGTA
# ATGTAGAGCGC -> TGTAGAGCGCC
# ATGTCACAGAC -> TGTCACAGACT
# ATGTGAACCGG -> TGTGAACCGGC
# ATGTGACGGCC -> TGTGACGGCCC
# ATGTGCGACCA -> TGTGCGACCAC
# ATGTGTCTAAA -> TGTGTCTAAAA
# ATGTTATATTT -> TGTTATATTTC
# ATGTTATGTGC -> TGTTATGTGCG
# ATTAACAAAAT -> TTAACAAAATA
# ATTAATAGACC -> TTAATAGACCG
# ATTAATCAAAT -> TTAATCAAATC
# ATTAATGGCTA -> TTAATGGCTAT
# ATTACCTAGAA -> TTACCTAGAAG
# ATTACGTCACT -> TTACGTCACTC
# ATTACTAGTCC -> TTACTAGTCCG
# ATTACTCGTGT -> TTACTCGTGTC
# ATTAGGACAAA -> TTAGGACAAAG
# ATTAGGAGGGC -> TTAGGAGGGCC
# ATTAGTTGCAT -> TTAGTTGCATT
# ATTATGACTGT -> TTATGACTGTA
# ATTATTCCATG -> TTATTCCATGG
# ATTCAAGAGCC -> TTCAAGAGCCG
# ATTCACACACG -> TTCACACACGT
# ATTCACGACAA -> TTCACGACAAG
# ATTCCATCATG -> TTCCATCATGA
# ATTCCATGGCA -> TTCCATGGCAA
# ATTCCGCCAAT -> TTCCGCCAATC
# ATTCCGCCTGA -> TTCCGCCTGAG
# ATTCGCACACC -> TTCGCACACCT
# ATTCGGTTCCG -> TTCGGTTCCGG
# ATTCTCTTCGA -> TTCTCTTCGAG
# ATTGAAGGCTC -> TTGAAGGCTCA
# ATTGCCAGGAT -> TTGCCAGGATT
# ATTGCCCCCGT -> TTGCCCCCGTC
# ATTGTATCGGC -> TTGTATCGGCA
# ATTGTTTCAAT -> TTGTTTCAATT
# ATTTAGAGACA -> TTTAGAGACAG
# ATTTCTCCGAA -> TTTCTCCGAAG
# ATTTGGCGCTA -> TTTGGCGCTAC
# ATTTTCAAGCC -> TTTTCAAGCCT
# ATTTTCTAGGG -> TTTTCTAGGGC
# ATTTTGAGGCT -> TTTTGAGGCTA
# CAAAATACTGC -> AAAATACTGCT
# CAAAATATGGG -> AAAATATGGGG
# CAAACCAACGC -> AAACCAACGCG
# CAAAGATTAAC -> AAAGATTAACA
# CAAAGGTCATC -> AAAGGTCATCA
# CAAATACACAT -> AAATACACATG
# CAAATAGGTTT -> AAATAGGTTTA
# CAAATCCAATG -> AAATCCAATGT
# CAAATTTGGCG -> AAATTTGGCGC
# CAACACAGTGG -> AACACAGTGGT
# CAACAGTAACC -> AACAGTAACCC
# CAACATCATTC -> AACATCATTCG
# CAACATCTATG -> AACATCTATGC
# CAACCCAATCA -> AACCCAATCAT
# CAACCGTTCCC -> AACCGTTCCCT
# CAACGCGTAAA -> AACGCGTAAAT
# CAACGTAATTC -> AACGTAATTCT
# CAACTAAGGAT -> AACTAAGGATT
# CAACTACCCGA -> AACTACCCGAT
# CAACTTGGCCT -> AACTTGGCCTC
# CAAGACAAGTC -> AAGACAAGTCC
# CAAGACTGATC -> AAGACTGATCT
# CAAGAGCCGCT -> AAGAGCCGCTT
# CAAGATAATGA -> AAGATAATGAT
# CAAGATCAATC -> AAGATCAATCA
# CAAGCCTGCTA -> AAGCCTGCTAG
# CAAGGCAACTT -> AAGGCAACTTG
# CAAGGCCCGTA -> AAGGCCCGTAC
# CAAGGCGGCAA -> AAGGCGGCAAT
# CAAGGTATAAC -> AAGGTATAACC
# CAAGTCCACTA -> AAGTCCACTAA
# CAAGTCCACTC -> AAGTCCACTCA
# CAATAGCGAGT -> AATAGCGAGTT
# CAATCAAGGCA -> AATCAAGGCAA
# CAATCATGCTG -> AATCATGCTGG
# CAATCATTATG -> AATCATTATGA
# CAATCCTCGAA -> AATCCTCGAAG
# CAATGACGGTG -> AATGACGGTGT
# CAATGCTAGGA -> AATGCTAGGAC
# CAATGTAGAGC -> AATGTAGAGCG
# CAATGTGAACC -> AATGTGAACCG
# CAATGTGTCTA -> AATGTGTCTAA
# CAATTGCCAGG -> AATTGCCAGGA
# CAATTTTCAAG -> AATTTTCAAGC
# CACAACAGTAA -> ACAACAGTAAC
# CACAAGACAAG -> ACAAGACAAGT
# CACAATAGCGA -> ACAATAGCGAG
# CACAATGTGTC -> ACAATGTGTCT
# CACACACGTTC -> ACACACGTTCC
# CACACCTGTAG -> ACACCTGTAGG
# CACACGTTCCT -> ACACGTTCCTA
# CACAGAATCAT -> ACAGAATCATT
# CACAGACTGTG -> ACAGACTGTGC
# CACAGCACAAT -> ACAGCACAATG
# CACAGCGATTT -> ACAGCGATTTA
# CACAGTGGTAG -> ACAGTGGTAGA
# CACATGGCGGG -> ACATGGCGGGT
# CACCAGTACAT -> ACCAGTACATC
# CACCGATGCCT -> ACCGATGCCTG
# CACCGCCGGAA -> ACCGCCGGAAG
# CACCGGTTACC -> ACCGGTTACCC
# CACCTAATCTG -> ACCTAATCTGG
# CACCTAGAGGA -> ACCTAGAGGAC
# CACCTGTAGGC -> ACCTGTAGGCG
# CACGACAAGGC -> ACGACAAGGCG
# CACGAGAGAAG -> ACGAGAGAAGG
# CACGATCGAAA -> ACGATCGAAAA
# CACGTGATGCA -> ACGTGATGCAT
# CACGTTCCTAG -> ACGTTCCTAGT
# CACTAAAACGG -> ACTAAAACGGG
# CACTAACTGGC -> ACTAACTGGCG
# CACTACCAACA -> ACTACCAACAT
# CACTATGAGTT -> ACTATGAGTTA
# CACTCAAAGGT -> ACTCAAAGGTC
# CACTCACCTAG -> ACTCACCTAGA
# CACTCAGAGTA -> ACTCAGAGTAT
# CACTCGCCGTG -> ACTCGCCGTGC
# CACTCGGCAAA -> ACTCGGCAAAT
# CACTCTTATAA -> ACTCTTATAAT
# CAGAATCATTC -> AGAATCATTCC
# CAGAATGCGGC -> AGAATGCGGCT
# CAGACCGCTTT -> AGACCGCTTTC
# CAGACTGTGCT -> AGACTGTGCTC
# CAGAGCGTGAG -> AGAGCGTGAGA
# CAGAGGAATAT -> AGAGGAATATC
# CAGAGGGCTTG -> AGAGGGCTTGG
# CAGAGTATTAC -> AGAGTATTACC
# CAGCAATGACG -> AGCAATGACGG
# CAGCACAATGT -> AGCACAATGTG
# CAGCGATTTAG -> AGCGATTTAGA
# CAGCGCAAGAT -> AGCGCAAGATC
# CAGGATCGCCA -> AGGATCGCCAA
# CAGGATTCAAG -> AGGATTCAAGA
# CAGGATTTTCT -> AGGATTTTCTA
# CAGGCACGTGA -> AGGCACGTGAT
# CAGGCTAAGAA -> AGGCTAAGAAC
# CAGGTAGTTGG -> AGGTAGTTGGG
# CAGTAACCCTG -> AGTAACCCTGT
# CAGTACATCGC -> AGTACATCGCG
# CAGTAGTGTAT -> AGTAGTGTATC
# CAGTCATTAAT -> AGTCATTAATC
# CAGTCGACATC -> AGTCGACATCG
# CAGTCGTTACT -> AGTCGTTACTA
# CAGTCGTTTAC -> AGTCGTTTACA
# CAGTCTTATTA -> AGTCTTATTAC
# CAGTGGTAGAC -> AGTGGTAGACT
# CAGTGGTGCAA -> AGTGGTGCAAC
# CATATTAATGG -> ATATTAATGGC
# CATATTCGCAC -> ATATTCGCACA
# CATATTGCCCC -> ATATTGCCCCC
# CATCAAATTTG -> ATCAAATTTGG
# CATCAGAGGGC -> ATCAGAGGGCT
# CATCAGGCTAA -> ATCAGGCTAAG
# CATCAGTCTTA -> ATCAGTCTTAT
# CATCATGATTA -> ATCATGATTAT
# CATCATTCGGT -> ATCATTCGGTT
# CATCGCGGAGT -> ATCGCGGAGTG
# CATCGGCTCTC -> ATCGGCTCTCC
# CATCTATGCAA -> ATCTATGCAAG
# CATCTCGATCT -> ATCTCGATCTT
# CATGATTATTC -> ATGATTATTCC
# CATGCGTACCT -> ATGCGTACCTG
# CATGCTGGGGC -> ATGCTGGGGCA
# CATGGATCAAG -> ATGGATCAAGG
# CATGGCAAGAT -> ATGGCAAGATA
# CATGGCGGGTT -> ATGGCGGGTTG
# CATGGTACACC -> ATGGTACACCG
# CATGGTTGGGC -> ATGGTTGGGCC
# CATGTGACGGC -> ATGTGACGGCC
# CATGTTATATT -> ATGTTATATTT
# CATTAATAGAC -> ATTAATAGACC
# CATTAATCAAA -> ATTAATCAAAT
# CATTACTCGTG -> ATTACTCGTGT
# CATTATGACTG -> ATTATGACTGT
# CATTCCGCCAA -> ATTCCGCCAAT
# CATTCGGTTCC -> ATTCGGTTCCG
# CATTGAAGGCT -> ATTGAAGGCTC
# CCAACATCATT -> CAACATCATTC
# CCAACCGTTCC -> CAACCGTTCCC
# CCAACGCGTAA -> CAACGCGTAAA
# CCAACTAAGGA -> CAACTAAGGAT
# CCAATCATGCT -> CAATCATGCTG
# CCAATCATTAT -> CAATCATTATG
# CCAATCCTCGA -> CAATCCTCGAA
# CCAATGTAGAG -> CAATGTAGAGC
# CCAATGTGAAC -> CAATGTGAACC
# CCACAGAATCA -> CACAGAATCAT
# CCACAGCACAA -> CACAGCACAAT
# CCACGAGAGAA -> CACGAGAGAAG
# CCACGATCGAA -> CACGATCGAAA
# CCACTAAAACG -> CACTAAAACGG
# CCACTAACTGG -> CACTAACTGGC
# CCACTCAAAGG -> CACTCAAAGGT
# CCAGGATTTTC -> CAGGATTTTCT
# CCAGTACATCG -> CAGTACATCGC
# CCAGTGGTGCA -> CAGTGGTGCAA
# CCATATTGCCC -> CATATTGCCCC
# CCATCATGATT -> CATCATGATTA
# CCATGCGTACC -> CATGCGTACCT
# CCATGGCAAGA -> CATGGCAAGAT
# CCATGGTTGGG -> CATGGTTGGGC
# CCATTGAAGGC -> CATTGAAGGCT
# CCCAATCATGC -> CCAATCATGCT
# CCCAGTGGTGC -> CCAGTGGTGCA
# CCCCAGTGGTG -> CCCAGTGGTGC
# CCCCCCTCATG -> CCCCCTCATGT
# CCCCCGTCTAA -> CCCCGTCTAAG
# CCCCCTCAACG -> CCCCTCAACGT
# CCCCCTCATGT -> CCCCTCATGTT
# CCCCGAAACAG -> CCCGAAACAGT
# CCCCGCTAATA -> CCCGCTAATAT
# CCCCGTCTAAG -> CCCGTCTAAGG
# CCCCTCAACGT -> CCCTCAACGTA
# CCCCTCATGTT -> CCCTCATGTTA
# CCCCTCGCGAA -> CCCTCGCGAAA
# CCCGAAACAGT -> CCGAAACAGTC
# CCCGATCACCG -> CCGATCACCGC
# CCCGCAGGCAC -> CCGCAGGCACG
# CCCGCGCCGGA -> CCGCGCCGGAC
# CCCGCTAATAT -> CCGCTAATATG
# CCCGTACCGGG -> CCGTACCGGGG
# CCCGTATAATT -> CCGTATAATTC
# CCCGTCTAAGG -> CCGTCTAAGGA
# CCCTATACTGA -> CCTATACTGAC
# CCCTCAAACCA -> CCTCAAACCAA
# CCCTCAACGTA -> CCTCAACGTAA
# CCCTCATGTTA -> CCTCATGTTAT
# CCCTCGCGAAA -> CCTCGCGAAAC
# CCCTGACCGAT -> CCTGACCGATT
# CCCTGGCAACA -> CCTGGCAACAT
# CCCTGTGCGGG -> CCTGTGCGGGT
# CCCTTAGGCAG -> CCTTAGGCAGA
# CCGAAACAGTC -> CGAAACAGTCG
# CCGAAGGGCTG -> CGAAGGGCTGA
# CCGACCATGCG -> CGACCATGCGT
# CCGATCACCGC -> CGATCACCGCC
# CCGATGAGGCT -> CGATGAGGCTA
# CCGATGCCTGT -> CGATGCCTGTG
# CCGATTACGTC -> CGATTACGTCA
# CCGATTAGGAC -> CGATTAGGACA
# CCGCAGGCACG -> CGCAGGCACGT
# CCGCCAATCCT -> CGCCAATCCTC
# CCGCCGGAAGA -> CGCCGGAAGAC
# CCGCCTGAGCT -> CGCCTGAGCTA
# CCGCGATAAAT -> CGCGATAAATG
# CCGCGCCGGAC -> CGCGCCGGACA
# CCGCGCTGCCA -> CGCGCTGCCAT
# CCGCGTAACCT -> CGCGTAACCTG
# CCGCTAATATG -> CGCTAATATGC
# CCGCTATCAAG -> CGCTATCAAGT
# CCGCTTGTGCG -> CGCTTGTGCGC
# CCGCTTTCATG -> CGCTTTCATGG
# CCGGAAAGTTC -> CGGAAAGTTCG
# CCGGAAGACAA -> CGGAAGACAAA
# CCGGAATTGTA -> CGGAATTGTAT
# CCGGACAAAAT -> CGGACAAAATA
# CCGGACTAACC -> CGGACTAACCC
# CCGGCTATATA -> CGGCTATATAA
# CCGGGAATCCA -> CGGGAATCCAT
# CCGGGGCGCTG -> CGGGGCGCTGC
# CCGGTTACCCG -> CGGTTACCCGT
# CCGTACCGGGG -> CGTACCGGGGC
# CCGTACTCAGG -> CGTACTCAGGA
# CCGTATAATTC -> CGTATAATTCA
# CCGTCTAAGGA -> CGTCTAAGGAT
# CCGTGCCAACT -> CGTGCCAACTA
# CCGTGTCATTA -> CGTGTCATTAC
# CCGTTCCCTGG -> CGTTCCCTGGC
# CCGTTCTGCCG -> CGTTCTGCCGG
# CCTAATCTGGT -> CTAATCTGGTT
# CCTACACTCAG -> CTACACTCAGA
# CCTAGAAGTAT -> CTAGAAGTATA
# CCTAGAGGACT -> CTAGAGGACTC
# CCTAGTGTGTA -> CTAGTGTGTAA
# CCTATACTGAC -> CTATACTGACC
# CCTCAAACCAA -> CTCAAACCAAC
# CCTCAACGTAA -> CTCAACGTAAT
# CCTCACTACCA -> CTCACTACCAA
# CCTCATGTTAT -> CTCATGTTATA
# CCTCGAAGTGT -> CTCGAAGTGTT
# CCTCGCGAAAC -> CTCGCGAAACG
# CCTCTGATCGG -> CTCTGATCGGA
# CCTCTGCTGAG -> CTCTGCTGAGT
# CCTCTTTACCC -> CTCTTTACCCC
# CCTGACCGATT -> CTGACCGATTA
# CCTGAGCTATG -> CTGAGCTATGC
# CCTGATCTGTG -> CTGATCTGTGC
# CCTGCTAGGAG -> CTGCTAGGAGG
# CCTGCTTATCA -> CTGCTTATCAT
# CCTGGCAACAT -> CTGGCAACATC
# CCTGGTGAGGC -> CTGGTGAGGCT
# CCTGTAACGAG -> CTGTAACGAGA
# CCTGTAGGCGT -> CTGTAGGCGTA
# CCTGTGCGGGT -> CTGTGCGGGTC
# CCTGTGGCTTG -> CTGTGGCTTGG
# CCTTAGGCAGA -> CTTAGGCAGAG
# CCTTATACGAA -> CTTATACGAAT
# CCTTGGTCGTA -> CTTGGTCGTAC
# CCTTGTTTCCG -> CTTGTTTCCGC
# CGAAAACCATG -> GAAAACCATGG
# CGAAACAGTCG -> GAAACAGTCGT
# CGAAACGCCAA -> GAAACGCCAAC
# CGAAGGGCTGA -> GAAGGGCTGAT
# CGAAGTGTTTA -> GAAGTGTTTAG
# CGAATAGCACC -> GAATAGCACCG
# CGAATATGCTT -> GAATATGCTTT
# CGACAAGGCGG -> GACAAGGCGGC
# CGACATCGGCT -> GACATCGGCTC
# CGACCACAGCA -> GACCACAGCAC
# CGACCATGCGT -> GACCATGCGTA
# CGAGAAGTCGT -> GAGAAGTCGTT
# CGAGACAGTCG -> GAGACAGTCGA
# CGAGAGAAGGG -> GAGAGAAGGGA
# CGAGCACAAGA -> GAGCACAAGAC
# CGAGGCAATTT -> GAGGCAATTTT
# CGAGGCAGAGC -> GAGGCAGAGCG
# CGAGGCCTCTT -> GAGGCCTCTTT
# CGAGGGGTCTA -> GAGGGGTCTAC
# CGAGTTATCGT -> GAGTTATCGTG
# CGAGTTGTTGG -> GAGTTGTTGGC
# CGATAAATGGC -> GATAAATGGCT
# CGATCACCGCC -> GATCACCGCCG
# CGATCGAAAAC -> GATCGAAAACC
# CGATCTTATCG -> GATCTTATCGA
# CGATGAGGCTA -> GATGAGGCTAG
# CGATGCCTGTG -> GATGCCTGTGG
# CGATTACGTCA -> GATTACGTCAC
# CGATTAGGACA -> GATTAGGACAA
# CGATTTAGAGA -> GATTTAGAGAC
# CGATTTTGAGG -> GATTTTGAGGC
# CGCAAGATCAA -> GCAAGATCAAT
# CGCACACCTGT -> GCACACCTGTA
# CGCAGGCACGT -> GCAGGCACGTG
# CGCATCTCGAT -> GCATCTCGATC
# CGCATGTGACG -> GCATGTGACGG
# CGCCAACCGTT -> GCCAACCGTTC
# CGCCAATCATT -> GCCAATCATTA
# CGCCAATCCTC -> GCCAATCCTCG
# CGCCAATGTGA -> GCCAATGTGAA
# CGCCGCTATCA -> GCCGCTATCAA
# CGCCGGAAGAC -> GCCGGAAGACA
# CGCCGGACAAA -> GCCGGACAAAA
# CGCCGTGCCAA -> GCCGTGCCAAC
# CGCCTGAGCTA -> GCCTGAGCTAT
# CGCCTGGTGAG -> GCCTGGTGAGG
# CGCGAAACGCC -> GCGAAACGCCA
# CGCGATAAATG -> GCGATAAATGG
# CGCGCCGGACA -> GCGCCGGACAA
# CGCGCGCGGTT -> GCGCGCGGTTA
# CGCGCGGTTAA -> GCGCGGTTAAA
# CGCGCTGCCAT -> GCGCTGCCATT
# CGCGGAGTGTG -> GCGGAGTGTGC
# CGCGGTTAAAC -> GCGGTTAAACC
# CGCGTAAATAC -> GCGTAAATACG
# CGCGTAACCTG -> GCGTAACCTGT
# CGCTAATATGC -> GCTAATATGCC
# CGCTACACTCG -> GCTACACTCGC
# CGCTATCAAGT -> GCTATCAAGTC
# CGCTCGGTAAG -> GCTCGGTAAGT
# CGCTGCCATTG -> GCTGCCATTGA
# CGCTGCGAGGC -> GCTGCGAGGCA
# CGCTTGTGCGC -> GCTTGTGCGCC
# CGCTTTCATGG -> GCTTTCATGGA
# CGGAAAGTTCG -> GGAAAGTTCGG
# CGGAAGACAAA -> GGAAGACAAAT
# CGGAATTGTAT -> GGAATTGTATC
# CGGACAAAATA -> GGACAAAATAT
# CGGACTAACCC -> GGACTAACCCG
# CGGAGTGTGCC -> GGAGTGTGCCG
# CGGATCGCCGC -> GGATCGCCGCT
# CGGCAAATACA -> GGCAAATACAC
# CGGCAATGCTA -> GGCAATGCTAG
# CGGCAGGATTC -> GGCAGGATTCA
# CGGCAGTAGTG -> GGCAGTAGTGT
# CGGCCCTCAAA -> GGCCCTCAAAC
# CGGCGTCCCTG -> GGCGTCCCTGA
# CGGCTATATAA -> GGCTATATAAT
# CGGCTCTCCGG -> GGCTCTCCGGA
# CGGCTTTGCTA -> GGCTTTGCTAC
# CGGGAACCTCT -> GGGAACCTCTG
# CGGGAATCCAT -> GGGAATCCATA
# CGGGCCTACAC -> GGGCCTACACT
# CGGGGCGCTGC -> GGGGCGCTGCG
# CGGGTCTGTAT -> GGGTCTGTATA
# CGGGTTGATTC -> GGGTTGATTCA
# CGGTAAGTGTT -> GGTAAGTGTTG
# CGGTCCACGAT -> GGTCCACGATC
# CGGTGTTAACA -> GGTGTTAACAC
# CGGTTAAACCC -> GGTTAAACCCC
# CGGTTACCCGT -> GGTTACCCGTA
# CGGTTCCGGAC -> GGTTCCGGACT
# CGTAAATACGC -> GTAAATACGCA
# CGTAACCTGTA -> GTAACCTGTAA
# CGTAATTCTCT -> GTAATTCTCTT
# CGTACCGGGGC -> GTACCGGGGCG
# CGTACCTGATC -> GTACCTGATCT
# CGTACGATTTT -> GTACGATTTTG
# CGTACTCAGGA -> GTACTCAGGAT
# CGTATAATTCA -> GTATAATTCAC
# CGTATAGTCAG -> GTATAGTCAGG
# CGTATTAGGAG -> GTATTAGGAGG
# CGTCACTCACC -> GTCACTCACCT
# CGTCAGCGCAA -> GTCAGCGCAAG
# CGTCCCTGACC -> GTCCCTGACCG
# CGTCGGTCCAC -> GTCGGTCCACG
# CGTCTAAGGAT -> GTCTAAGGATC
# CGTGAGACACC -> GTGAGACACCT
# CGTGATGCATC -> GTGATGCATCA
# CGTGCCAACTA -> GTGCCAACTAA
# CGTGCCTTGGT -> GTGCCTTGGTC
# CGTGGTTTTCG -> GTGGTTTTCGA
# CGTGTCATTAC -> GTGTCATTACT
# CGTGTCGCATA -> GTGTCGCATAC
# CGTTACTATCC -> GTTACTATCCC
# CGTTCCCTGGC -> GTTCCCTGGCA
# CGTTCCTAGTG -> GTTCCTAGTGT
# CGTTCTGCCGG -> GTTCTGCCGGA
# CGTTTACACCA -> GTTTACACCAG
# CGTTTTGGGGG -> GTTTTGGGGGA
# CTAAAAAAGTC -> TAAAAAAGTCT
# CTAAAACGGGC -> TAAAACGGGCC
# CTAACCCGCGC -> TAACCCGCGCC
# CTAACTGGCGA -> TAACTGGCGAG
# CTAAGAACACT -> TAAGAACACTA
# CTAAGGAGTGA -> TAAGGAGTGAG
# CTAAGGATCGA -> TAAGGATCGAG
# CTAAGGATTGT -> TAAGGATTGTT
# CTAATATGCCC -> TAATATGCCCG
# CTAATCTGGTT -> TAATCTGGTTA
# CTACACTCAGA -> TACACTCAGAG
# CTACACTCGCC -> TACACTCGCCG
# CTACCAACATC -> TACCAACATCA
# CTACCCCTCGC -> TACCCCTCGCG
# CTACCCGATCA -> TACCCGATCAC
# CTACTCTTGGC -> TACTCTTGGCG
# CTAGAAGTATA -> TAGAAGTATAC
# CTAGAGGACTC -> TAGAGGACTCC
# CTAGGACCCCA -> TAGGACCCCAG
# CTAGGAGGCAG -> TAGGAGGCAGT
# CTAGGGCTTGG -> TAGGGCTTGGT
# CTAGTCCGACC -> TAGTCCGACCA
# CTAGTGACCGG -> TAGTGACCGGG
# CTAGTGTGTAA -> TAGTGTGTAAC
# CTATACTGACC -> TATACTGACCA
# CTATATAATAT -> TATATAATATA
# CTATCAAGTCC -> TATCAAGTCCA
# CTATCACAATA -> TATCACAATAG
# CTATCCCCGAA -> TATCCCCGAAA
# CTATGAGTTAT -> TATGAGTTATC
# CTATGCAAGAC -> TATGCAAGACT
# CTATGCCGCGA -> TATGCCGCGAT
# CTATTCCATCA -> TATTCCATCAT
# CTCAAACCAAC -> TCAAACCAACG
# CTCAAAGGTCA -> TCAAAGGTCAT
# CTCAACGTAAT -> TCAACGTAATT
# CTCACCTAGAG -> TCACCTAGAGG
# CTCACTACCAA -> TCACTACCAAC
# CTCAGAATGCG -> TCAGAATGCGG
# CTCAGAGTATT -> TCAGAGTATTA
# CTCAGGATCGC -> TCAGGATCGCC
# CTCATATTAAT -> TCATATTAATG
# CTCATGTTATA -> TCATGTTATAT
# CTCCCTTAGGC -> TCCCTTAGGCA
# CTCCGAAGGGC -> TCCGAAGGGCT
# CTCCGATGAGG -> TCCGATGAGGC
# CTCCGATTAGG -> TCCGATTAGGA
# CTCCGGAAAGT -> TCCGGAAAGTT
# CTCGAAGTGTT -> TCGAAGTGTTT
# CTCGATCTTAT -> TCGATCTTATC
# CTCGCCGTGCC -> TCGCCGTGCCA
# CTCGCGAAACG -> TCGCGAAACGC
# CTCGGCAAATA -> TCGGCAAATAC
# CTCGGTAAGTG -> TCGGTAAGTGT
# CTCGTCAGCGC -> TCGTCAGCGCA
# CTCGTGGTTTT -> TCGTGGTTTTC
# CTCGTGTCGCA -> TCGTGTCGCAT
# CTCTCCGGAAA -> TCTCCGGAAAG
# CTCTGATCGGA -> TCTGATCGGAT
# CTCTGCTGAGT -> TCTGCTGAGTT
# CTCTTATAATG -> TCTTATAATGT
# CTCTTCGAGAA -> TCTTCGAGAAG
# CTCTTGGCGCA -> TCTTGGCGCAT
# CTCTTTACCCC -> TCTTTACCCCG
# CTGAAATAACA -> TGAAATAACAG
# CTGACCACGAG -> TGACCACGAGA
# CTGACCGATTA -> TGACCGATTAC
# CTGACGTCGGT -> TGACGTCGGTC
# CTGAGCTATGC -> TGAGCTATGCC
# CTGAGTTGAAA -> TGAGTTGAAAT
# CTGATCGGATC -> TGATCGGATCG
# CTGATCTGTGC -> TGATCTGTGCC
# CTGATCTGTTT -> TGATCTGTTTG
# CTGATGGTTTC -> TGATGGTTTCA
# CTGATGTCACA -> TGATGTCACAG
# CTGCCATTGAA -> TGCCATTGAAG
# CTGCCGGAATT -> TGCCGGAATTG
# CTGCGAGGCAA -> TGCGAGGCAAT
# CTGCTAGGAGG -> TGCTAGGAGGC
# CTGCTCGTCAG -> TGCTCGTCAGC
# CTGCTGAGTTG -> TGCTGAGTTGA
# CTGCTTATCAT -> TGCTTATCATC
# CTGGCAACATC -> TGGCAACATCT
# CTGGCGAGGCA -> TGGCGAGGCAG
# CTGGGCACAGC -> TGGGCACAGCG
# CTGGGGCAACA -> TGGGGCAACAC
# CTGGTGAGGCT -> TGGTGAGGCTC
# CTGGTTAAAGT -> TGGTTAAAGTT
# CTGTAAAACAA -> TGTAAAACAAC
# CTGTAACGAGA -> TGTAACGAGAC
# CTGTAGGCGTA -> TGTAGGCGTAT
# CTGTATATGTT -> TGTATATGTTA
# CTGTGCCCTAT -> TGTGCCCTATA
# CTGTGCGGGTC -> TGTGCGGGTCT
# CTGTGCTCCCT -> TGTGCTCCCTT
# CTGTGGCTTGG -> TGTGGCTTGGG
# CTGTTTGTTGC -> TGTTTGTTGCG
# CTTAGGCAGAG -> TTAGGCAGAGG
# CTTATAATGTA -> TTATAATGTAC
# CTTATACGAAT -> TTATACGAATA
# CTTATCATCAG -> TTATCATCAGT
# CTTATCGAGGC -> TTATCGAGGCC
# CTTATTACTAG -> TTATTACTAGT
# CTTCGAGAAGT -> TTCGAGAAGTC
# CTTCGCGCGCG -> TTCGCGCGCGG
# CTTGGCCTCAC -> TTGGCCTCACT
# CTTGGCGCATG -> TTGGCGCATGT
# CTTGGGGCTGG -> TTGGGGCTGGG
# CTTGGTCCTGC -> TTGGTCCTGCT
# CTTGGTCGTAC -> TTGGTCGTACG
# CTTGGTCTGAA -> TTGGTCTGAAA
# CTTGTGCGCCT -> TTGTGCGCCTG
# CTTGTTTCCGC -> TTGTTTCCGCG
# CTTTACCCCGC -> TTTACCCCGCT
# CTTTCATGGAT -> TTTCATGGATC
# CTTTGCTACTC -> TTTGCTACTCT
# CTTTGTCCGTG -> TTTGTCCGTGT
# GAAAACCATGG -> AAAACCATGGT
# GAAACAGTCGT -> AAACAGTCGTT
# GAAACCTCTGA -> AAACCTCTGAT
# GAAACGCCAAC -> AAACGCCAACC
# GAAAGTTCGGG -> AAAGTTCGGGA
# GAAATAACAGC -> AAATAACAGCA
# GAAATACATGG -> AAATACATGGT
# GAACACTATGA -> AACACTATGAG
# GAACCGGCTAT -> AACCGGCTATA
# GAACCTCTGCT -> AACCTCTGCTG
# GAAGACAAATA -> AAGACAAATAG
# GAAGCGAATAG -> AAGCGAATAGC
# GAAGGCTCAGA -> AAGGCTCAGAA
# GAAGGGATTCC -> AAGGGATTCCG
# GAAGGGCTGAT -> AAGGGCTGATG
# GAAGTATACAT -> AAGTATACATA
# GAAGTCGTTTT -> AAGTCGTTTTG
# GAAGTGTTTAG -> AAGTGTTTAGA
# GAATAGCACCG -> AATAGCACCGG
# GAATATCTCCG -> AATATCTCCGA
# GAATATGCTTT -> AATATGCTTTG
# GAATCATTCCG -> AATCATTCCGC
# GAATCCATATT -> AATCCATATTG
# GAATGCGGCTT -> AATGCGGCTTT
# GAATTGTATCG -> AATTGTATCGG
# GACAAAATATG -> ACAAAATATGG
# GACAAAGATTA -> ACAAAGATTAA
# GACAAATAGGT -> ACAAATAGGTT
# GACAAGGCGGC -> ACAAGGCGGCA
# GACAAGTCCAC -> ACAAGTCCACT
# GACACCTAATC -> ACACCTAATCT
# GACAGTCATTA -> ACAGTCATTAA
# GACAGTCGACA -> ACAGTCGACAT
# GACATCGGCTC -> ACATCGGCTCT
# GACCACAGCAC -> ACCACAGCACA
# GACCACGAGAG -> ACCACGAGAGA
# GACCATGCGTA -> ACCATGCGTAC
# GACCCCAGTGG -> ACCCCAGTGGT
# GACCGATTACG -> ACCGATTACGT
# GACCGCTTTCA -> ACCGCTTTCAT
# GACCGGGAATC -> ACCGGGAATCC
# GACCGTACTCA -> ACCGTACTCAG
# GACGAGGGGTC -> ACGAGGGGTCT
# GACGGCCCTCA -> ACGGCCCTCAA
# GACGGTGTTAA -> ACGGTGTTAAC
# GACGTCGGTCC -> ACGTCGGTCCA
# GACTAACCCGC -> ACTAACCCGCG
# GACTCATATTA -> ACTCATATTAA
# GACTCCGATGA -> ACTCCGATGAG
# GACTGATCTGT -> ACTGATCTGTT
# GACTGTAAAAC -> ACTGTAAAACA
# GACTGTGCTCC -> ACTGTGCTCCC
# GAGAAGCGAAT -> AGAAGCGAATA
# GAGAAGGGATT -> AGAAGGGATTC
# GAGAAGTCGTT -> AGAAGTCGTTT
# GAGACACCTAA -> AGACACCTAAT
# GAGACAGTCAT -> AGACAGTCATT
# GAGACAGTCGA -> AGACAGTCGAC
# GAGAGAAGGGA -> AGAGAAGGGAT
# GAGATCCTTAT -> AGATCCTTATA
# GAGCACAAGAC -> AGCACAAGACA
# GAGCCGCTTGT -> AGCCGCTTGTG
# GAGCGCCAATG -> AGCGCCAATGT
# GAGCGTGAGAC -> AGCGTGAGACA
# GAGCTATGCCG -> AGCTATGCCGC
# GAGGAATATCT -> AGGAATATCTC
# GAGGACTCCGA -> AGGACTCCGAT
# GAGGCAATTTT -> AGGCAATTTTC
# GAGGCAGAGCG -> AGGCAGAGCGT
# GAGGCAGTCGT -> AGGCAGTCGTT
# GAGGCCTCTTT -> AGGCCTCTTTA
# GAGGCTAGTGA -> AGGCTAGTGAC
# GAGGCTATTCC -> AGGCTATTCCA
# GAGGCTCGTGG -> AGGCTCGTGGT
# GAGGGCCACTA -> AGGGCCACTAA
# GAGGGCTTGGT -> AGGGCTTGGTC
# GAGGGGTCTAC -> AGGGGTCTACC
# GAGTATTACCT -> AGTATTACCTA
# GAGTGAAACCT -> AGTGAAACCTC
# GAGTGAGATCC -> AGTGAGATCCT
# GAGTGTGCCGC -> AGTGTGCCGCG
# GAGTTATCAGA -> AGTTATCAGAC
# GAGTTATCGTG -> AGTTATCGTGC
# GAGTTGAAATA -> AGTTGAAATAC
# GAGTTGTTGGC -> AGTTGTTGGCC
# GATAAATGGCT -> ATAAATGGCTT
# GATAATGATTA -> ATAATGATTAG
# GATCAAGGCCC -> ATCAAGGCCCG
# GATCAATCAAG -> ATCAATCAAGG
# GATCACCGCCG -> ATCACCGCCGG
# GATCCTTATAC -> ATCCTTATACG
# GATCGAAAACC -> ATCGAAAACCA
# GATCGAGCACA -> ATCGAGCACAA
# GATCGCCAATC -> ATCGCCAATCA
# GATCGCCGCTA -> ATCGCCGCTAT
# GATCGGATCGC -> ATCGGATCGCC
# GATCTGTGCCC -> ATCTGTGCCCT
# GATCTGTTTGT -> ATCTGTTTGTT
# GATCTTATCGA -> ATCTTATCGAG
# GATGAGGCTAG -> ATGAGGCTAGT
# GATGCATCAGA -> ATGCATCAGAG
# GATGCCTGTGG -> ATGCCTGTGGC
# GATGGTTTCAC -> ATGGTTTCACT
# GATGTCACAGA -> ATGTCACAGAC
# GATTAACAAAA -> ATTAACAAAAT
# GATTACGTCAC -> ATTACGTCACT
# GATTAGGACAA -> ATTAGGACAAA
# GATTAGTTGCA -> ATTAGTTGCAT
# GATTATTCCAT -> ATTATTCCATG
# GATTCAAGAGC -> ATTCAAGAGCC
# GATTCACGACA -> ATTCACGACAA
# GATTCCGCCTG -> ATTCCGCCTGA
# GATTGTTTCAA -> ATTGTTTCAAT
# GATTTAGAGAC -> ATTTAGAGACA
# GATTTTCTAGG -> ATTTTCTAGGG
# GATTTTGAGGC -> ATTTTGAGGCT
# GCAAATACACA -> CAAATACACAT
# GCAACACAGTG -> CAACACAGTGG
# GCAACATCTAT -> CAACATCTATG
# GCAACTACCCG -> CAACTACCCGA
# GCAACTTGGCC -> CAACTTGGCCT
# GCAAGACTGAT -> CAAGACTGATC
# GCAAGATAATG -> CAAGATAATGA
# GCAAGATCAAT -> CAAGATCAATC
# GCAATGACGGT -> CAATGACGGTG
# GCAATGCTAGG -> CAATGCTAGGA
# GCAATTTTCAA -> CAATTTTCAAG
# GCACAACAGTA -> CACAACAGTAA
# GCACAAGACAA -> CACAAGACAAG
# GCACAATGTGT -> CACAATGTGTC
# GCACACCTGTA -> CACACCTGTAG
# GCACAGCGATT -> CACAGCGATTT
# GCACCGGTTAC -> CACCGGTTACC
# GCACGTGATGC -> CACGTGATGCA
# GCAGAGCGTGA -> CAGAGCGTGAG
# GCAGAGGAATA -> CAGAGGAATAT
# GCAGGATTCAA -> CAGGATTCAAG
# GCAGGCACGTG -> CAGGCACGTGA
# GCAGTAGTGTA -> CAGTAGTGTAT
# GCAGTCGTTAC -> CAGTCGTTACT
# GCATCAGAGGG -> CATCAGAGGGC
# GCATCTCGATC -> CATCTCGATCT
# GCATGTGACGG -> CATGTGACGGC
# GCATTAATAGA -> CATTAATAGAC
# GCCAACCGTTC -> CCAACCGTTCC
# GCCAACTAAGG -> CCAACTAAGGA
# GCCAATCATTA -> CCAATCATTAT
# GCCAATCCTCG -> CCAATCCTCGA
# GCCAATGTGAA -> CCAATGTGAAC
# GCCACAGAATC -> CCACAGAATCA
# GCCACTAACTG -> CCACTAACTGG
# GCCAGGATTTT -> CCAGGATTTTC
# GCCATTGAAGG -> CCATTGAAGGC
# GCCCCCGTCTA -> CCCCCGTCTAA
# GCCCCCTCAAC -> CCCCCTCAACG
# GCCCGCAGGCA -> CCCGCAGGCAC
# GCCCGTACCGG -> CCCGTACCGGG
# GCCCTATACTG -> CCCTATACTGA
# GCCCTCAAACC -> CCCTCAAACCA
# GCCGCGATAAA -> CCGCGATAAAT
# GCCGCGCTGCC -> CCGCGCTGCCA
# GCCGCTATCAA -> CCGCTATCAAG
# GCCGCTTGTGC -> CCGCTTGTGCG
# GCCGGAAGACA -> CCGGAAGACAA
# GCCGGAATTGT -> CCGGAATTGTA
# GCCGGACAAAA -> CCGGACAAAAT
# GCCGTGCCAAC -> CCGTGCCAACT
# GCCTACACTCA -> CCTACACTCAG
# GCCTCACTACC -> CCTCACTACCA
# GCCTCTTTACC -> CCTCTTTACCC
# GCCTGAGCTAT -> CCTGAGCTATG
# GCCTGCTAGGA -> CCTGCTAGGAG
# GCCTGGTGAGG -> CCTGGTGAGGC
# GCCTGTGGCTT -> CCTGTGGCTTG
# GCCTTGGTCGT -> CCTTGGTCGTA
# GCCTTGTTTCC -> CCTTGTTTCCG
# GCGAAACGCCA -> CGAAACGCCAA
# GCGAATAGCAC -> CGAATAGCACC
# GCGACCACAGC -> CGACCACAGCA
# GCGAGGCAATT -> CGAGGCAATTT
# GCGAGGCAGAG -> CGAGGCAGAGC
# GCGAGTTGTTG -> CGAGTTGTTGG
# GCGATAAATGG -> CGATAAATGGC
# GCGATTTAGAG -> CGATTTAGAGA
# GCGCAAGATCA -> CGCAAGATCAA
# GCGCATGTGAC -> CGCATGTGACG
# GCGCCAATGTG -> CGCCAATGTGA
# GCGCCGGACAA -> CGCCGGACAAA
# GCGCCTGGTGA -> CGCCTGGTGAG
# GCGCGCGGTTA -> CGCGCGGTTAA
# GCGCGGTTAAA -> CGCGGTTAAAC
# GCGCTACACTC -> CGCTACACTCG
# GCGCTGCCATT -> CGCTGCCATTG
# GCGCTGCGAGG -> CGCTGCGAGGC
# GCGGAGTGTGC -> CGGAGTGTGCC
# GCGGCAATGCT -> CGGCAATGCTA
# GCGGCAGTAGT -> CGGCAGTAGTG
# GCGGCTTTGCT -> CGGCTTTGCTA
# GCGGGTCTGTA -> CGGGTCTGTAT
# GCGGGTTGATT -> CGGGTTGATTC
# GCGGTTAAACC -> CGGTTAAACCC
# GCGTAAATACG -> CGTAAATACGC
# GCGTAACCTGT -> CGTAACCTGTA
# GCGTACCTGAT -> CGTACCTGATC
# GCGTATAGTCA -> CGTATAGTCAG
# GCGTATTAGGA -> CGTATTAGGAG
# GCGTCCCTGAC -> CGTCCCTGACC
# GCGTGAGACAC -> CGTGAGACACC
# GCTAAGAACAC -> CTAAGAACACT
# GCTAATATGCC -> CTAATATGCCC
# GCTACACTCGC -> CTACACTCGCC
# GCTACTCTTGG -> CTACTCTTGGC
# GCTAGGACCCC -> CTAGGACCCCA
# GCTAGGAGGCA -> CTAGGAGGCAG
# GCTAGTGACCG -> CTAGTGACCGG
# GCTATATAATA -> CTATATAATAT
# GCTATCAAGTC -> CTATCAAGTCC
# GCTATCACAAT -> CTATCACAATA
# GCTATGCCGCG -> CTATGCCGCGA
# GCTATTCCATC -> CTATTCCATCA
# GCTCAGAATGC -> CTCAGAATGCG
# GCTCCCTTAGG -> CTCCCTTAGGC
# GCTCGGTAAGT -> CTCGGTAAGTG
# GCTCGTCAGCG -> CTCGTCAGCGC
# GCTCGTGGTTT -> CTCGTGGTTTT
# GCTCTCCGGAA -> CTCTCCGGAAA
# GCTGAGTTGAA -> CTGAGTTGAAA
# GCTGATGTCAC -> CTGATGTCACA
# GCTGCCATTGA -> CTGCCATTGAA
# GCTGCGAGGCA -> CTGCGAGGCAA
# GCTGGGCACAG -> CTGGGCACAGC
# GCTGGGGCAAC -> CTGGGGCAACA
# GCTTATCATCA -> CTTATCATCAG
# GCTTCGCGCGC -> CTTCGCGCGCG
# GCTTGGGGCTG -> CTTGGGGCTGG
# GCTTGGTCCTG -> CTTGGTCCTGC
# GCTTGGTCTGA -> CTTGGTCTGAA
# GCTTGTGCGCC -> CTTGTGCGCCT
# GCTTTCATGGA -> CTTTCATGGAT
# GCTTTGCTACT -> CTTTGCTACTC
# GCTTTGTCCGT -> CTTTGTCCGTG
# GGAAAGTTCGG -> GAAAGTTCGGG
# GGAACCTCTGC -> GAACCTCTGCT
# GGAAGACAAAT -> GAAGACAAATA
# GGAATATCTCC -> GAATATCTCCG
# GGAATCCATAT -> GAATCCATATT
# GGAATTGTATC -> GAATTGTATCG
# GGACAAAATAT -> GACAAAATATG
# GGACAAAGATT -> GACAAAGATTA
# GGACCCCAGTG -> GACCCCAGTGG
# GGACTAACCCG -> GACTAACCCGC
# GGACTCCGATG -> GACTCCGATGA
# GGAGAAGCGAA -> GAGAAGCGAAT
# GGAGGCAGTCG -> GAGGCAGTCGT
# GGAGGGCCACT -> GAGGGCCACTA
# GGAGTGAAACC -> GAGTGAAACCT
# GGAGTGAGATC -> GAGTGAGATCC
# GGAGTGTGCCG -> GAGTGTGCCGC
# GGATCAAGGCC -> GATCAAGGCCC
# GGATCGAGCAC -> GATCGAGCACA
# GGATCGCCAAT -> GATCGCCAATC
# GGATCGCCGCT -> GATCGCCGCTA
# GGATTCAAGAG -> GATTCAAGAGC
# GGATTCCGCCT -> GATTCCGCCTG
# GGATTGTTTCA -> GATTGTTTCAA
# GGATTTTCTAG -> GATTTTCTAGG
# GGCAAATACAC -> GCAAATACACA
# GGCAACACAGT -> GCAACACAGTG
# GGCAACATCTA -> GCAACATCTAT
# GGCAACTTGGC -> GCAACTTGGCC
# GGCAAGATAAT -> GCAAGATAATG
# GGCAATGCTAG -> GCAATGCTAGG
# GGCAATTTTCA -> GCAATTTTCAA
# GGCACAACAGT -> GCACAACAGTA
# GGCACAGCGAT -> GCACAGCGATT
# GGCACGTGATG -> GCACGTGATGC
# GGCAGAGCGTG -> GCAGAGCGTGA
# GGCAGAGGAAT -> GCAGAGGAATA
# GGCAGGATTCA -> GCAGGATTCAA
# GGCAGTAGTGT -> GCAGTAGTGTA
# GGCAGTCGTTA -> GCAGTCGTTAC
# GGCCACAGAAT -> GCCACAGAATC
# GGCCACTAACT -> GCCACTAACTG
# GGCCCCCTCAA -> GCCCCCTCAAC
# GGCCCGTACCG -> GCCCGTACCGG
# GGCCCTCAAAC -> GCCCTCAAACC
# GGCCTACACTC -> GCCTACACTCA
# GGCCTCACTAC -> GCCTCACTACC
# GGCCTCTTTAC -> GCCTCTTTACC
# GGCCTTGTTTC -> GCCTTGTTTCC
# GGCGAGGCAGA -> GCGAGGCAGAG
# GGCGCATGTGA -> GCGCATGTGAC
# GGCGCTACACT -> GCGCTACACTC
# GGCGCTGCGAG -> GCGCTGCGAGG
# GGCGGCAATGC -> GCGGCAATGCT
# GGCGGCAGTAG -> GCGGCAGTAGT
# GGCGGGTTGAT -> GCGGGTTGATT
# GGCGTATTAGG -> GCGTATTAGGA
# GGCGTCCCTGA -> GCGTCCCTGAC
# GGCTAAGAACA -> GCTAAGAACAC
# GGCTAGTGACC -> GCTAGTGACCG
# GGCTATATAAT -> GCTATATAATA
# GGCTATCACAA -> GCTATCACAAT
# GGCTATTCCAT -> GCTATTCCATC
# GGCTCAGAATG -> GCTCAGAATGC
# GGCTCGTGGTT -> GCTCGTGGTTT
# GGCTCTCCGGA -> GCTCTCCGGAA
# GGCTGATGTCA -> GCTGATGTCAC
# GGCTGGGCACA -> GCTGGGCACAG
# GGCTTCGCGCG -> GCTTCGCGCGC
# GGCTTGGGGCT -> GCTTGGGGCTG
# GGCTTGGTCCT -> GCTTGGTCCTG
# GGCTTGGTCTG -> GCTTGGTCTGA
# GGCTTTGCTAC -> GCTTTGCTACT
# GGGAACCTCTG -> GGAACCTCTGC
# GGGAATCCATA -> GGAATCCATAT
# GGGAGAAGCGA -> GGAGAAGCGAA
# GGGAGTGAAAC -> GGAGTGAAACC
# GGGATTCCGCC -> GGATTCCGCCT
# GGGCAACACAG -> GGCAACACAGT
# GGGCACAACAG -> GGCACAACAGT
# GGGCACAGCGA -> GGCACAGCGAT
# GGGCCACAGAA -> GGCCACAGAAT
# GGGCCACTAAC -> GGCCACTAACT
# GGGCCTACACT -> GGCCTACACTC
# GGGCGCTGCGA -> GGCGCTGCGAG
# GGGCGGCAGTA -> GGCGGCAGTAG
# GGGCTGATGTC -> GGCTGATGTCA
# GGGCTGGGCAC -> GGCTGGGCACA
# GGGCTTGGTCC -> GGCTTGGTCCT
# GGGCTTGGTCT -> GGCTTGGTCTG
# GGGGAGAAGCG -> GGGAGAAGCGA
# GGGGCAACACA -> GGGCAACACAG
# GGGGCACAACA -> GGGCACAACAG
# GGGGCGCTGCG -> GGGCGCTGCGA
# GGGGCGGCAGT -> GGGCGGCAGTA
# GGGGCTGGGCA -> GGGCTGGGCAC
# GGGGGAGAAGC -> GGGGAGAAGCG
# GGGGGCGGCAG -> GGGGCGGCAGT
# GGGGTCTACCC -> GGGTCTACCCC
# GGGTCTACCCC -> GGTCTACCCCT
# GGGTCTGTATA -> GGTCTGTATAT
# GGGTTGATTCA -> GGTTGATTCAC
# GGTAAGTGTTG -> GTAAGTGTTGT
# GGTACACCGAT -> GTACACCGATG
# GGTAGACTCAT -> GTAGACTCATA
# GGTAGTTGGGG -> GTAGTTGGGGG
# GGTATAACCGT -> GTATAACCGTT
# GGTCATCAGGC -> GTCATCAGGCT
# GGTCCACGATC -> GTCCACGATCG
# GGTCCTGCTTA -> GTCCTGCTTAT
# GGTCGTACGAT -> GTCGTACGATT
# GGTCTACCCCT -> GTCTACCCCTC
# GGTCTGAAATA -> GTCTGAAATAA
# GGTCTGTATAT -> GTCTGTATATG
# GGTGAGGCTCG -> GTGAGGCTCGT
# GGTGCAACTAC -> GTGCAACTACC
# GGTGTTAACAC -> GTGTTAACACT
# GGTTAAACCCC -> GTTAAACCCCC
# GGTTAAAGTTA -> GTTAAAGTTAA
# GGTTACCCGTA -> GTTACCCGTAT
# GGTTCCGGACT -> GTTCCGGACTA
# GGTTGATTCAC -> GTTGATTCACG
# GGTTGGGCCAC -> GTTGGGCCACA
# GGTTTACATCA -> GTTTACATCAA
# GGTTTCACTCG -> GTTTCACTCGG
# GGTTTTCGAGT -> GTTTTCGAGTT
# GTAAAACAACC -> TAAAACAACCC
# GTAAATACGCA -> TAAATACGCAT
# GTAACCCTGTG -> TAACCCTGTGC
# GTAACCTGTAA -> TAACCTGTAAC
# GTAACGAGACA -> TAACGAGACAG
# GTAACTGACGT -> TAACTGACGTC
# GTAAGTGTTGT -> TAAGTGTTGTT
# GTAATTCTCTT -> TAATTCTCTTC
# GTACAAGGTAT -> TACAAGGTATA
# GTACACCGATG -> TACACCGATGC
# GTACATCGCGG -> TACATCGCGGA
# GTACCGGGGCG -> TACCGGGGCGC
# GTACCTGATCT -> TACCTGATCTG
# GTACGATTTTG -> TACGATTTTGA
# GTACTCAGGAT -> TACTCAGGATC
# GTAGACTCATA -> TAGACTCATAT
# GTAGAGCGCCA -> TAGAGCGCCAA
# GTAGGCGTATT -> TAGGCGTATTA
# GTAGTGTATCG -> TAGTGTATCGC
# GTAGTTGGGGG -> TAGTTGGGGGC
# GTATAACCGTT -> TATAACCGTTC
# GTATAATTCAC -> TATAATTCACA
# GTATACATATT -> TATACATATTC
# GTATAGTCAGG -> TATAGTCAGGT
# GTATATGTTAT -> TATATGTTATG
# GTATCGCTCGG -> TATCGCTCGGT
# GTATCGGCAGG -> TATCGGCAGGA
# GTATTACCTAG -> TATTACCTAGA
# GTATTAGGAGG -> TATTAGGAGGG
# GTCACAGACTG -> TCACAGACTGT
# GTCACTCACCT -> TCACTCACCTA
# GTCAGCGCAAG -> TCAGCGCAAGA
# GTCAGGTAGTT -> TCAGGTAGTTG
# GTCATCAGGCT -> TCATCAGGCTA
# GTCATTAATCA -> TCATTAATCAA
# GTCATTACTCG -> TCATTACTCGT
# GTCCACGATCG -> TCCACGATCGA
# GTCCACTAAAA -> TCCACTAAAAC
# GTCCACTCAAA -> TCCACTCAAAG
# GTCCCTGACCG -> TCCCTGACCGA
# GTCCGACCATG -> TCCGACCATGC
# GTCCGTGTCAT -> TCCGTGTCATT
# GTCCTGCTTAT -> TCCTGCTTATC
# GTCGACATCGG -> TCGACATCGGC
# GTCGCATACAA -> TCGCATACAAA
# GTCGGTCCACG -> TCGGTCCACGA
# GTCGTACGATT -> TCGTACGATTT
# GTCGTTACTAT -> TCGTTACTATC
# GTCGTTTACAC -> TCGTTTACACC
# GTCGTTTTGGG -> TCGTTTTGGGG
# GTCTAAAAAAG -> TCTAAAAAAGT
# GTCTAAGGAGT -> TCTAAGGAGTG
# GTCTAAGGATC -> TCTAAGGATCG
# GTCTACCCCTC -> TCTACCCCTCG
# GTCTGAAATAA -> TCTGAAATAAC
# GTCTGTATATG -> TCTGTATATGT
# GTCTTATTACT -> TCTTATTACTA
# GTGAAACCTCT -> TGAAACCTCTG
# GTGAACCGGCT -> TGAACCGGCTA
# GTGACCGGGAA -> TGACCGGGAAT
# GTGACGGCCCT -> TGACGGCCCTC
# GTGAGACACCT -> TGAGACACCTA
# GTGAGATCCTT -> TGAGATCCTTA
# GTGAGGCTCGT -> TGAGGCTCGTG
# GTGATGCATCA -> TGATGCATCAG
# GTGCAACTACC -> TGCAACTACCC
# GTGCCAACTAA -> TGCCAACTAAG
# GTGCCCTATAC -> TGCCCTATACT
# GTGCCGCGCTG -> TGCCGCGCTGC
# GTGCCTTGGTC -> TGCCTTGGTCG
# GTGCGACCACA -> TGCGACCACAG
# GTGCGCCTGGT -> TGCGCCTGGTG
# GTGCGGGTCTG -> TGCGGGTCTGT
# GTGCTCCCTTA -> TGCTCCCTTAG
# GTGGCTTGGGG -> TGGCTTGGGGC
# GTGGTAGACTC -> TGGTAGACTCA
# GTGGTGCAACT -> TGGTGCAACTA
# GTGGTTTTCGA -> TGGTTTTCGAG
# GTGTAACTGAC -> TGTAACTGACG
# GTGTATCGCTC -> TGTATCGCTCG
# GTGTCATTACT -> TGTCATTACTC
# GTGTCGCATAC -> TGTCGCATACA
# GTGTCTAAAAA -> TGTCTAAAAAA
# GTGTGCCGCGC -> TGTGCCGCGCT
# GTGTGTAACTG -> TGTGTAACTGA
# GTGTTAACACT -> TGTTAACACTC
# GTGTTGTTCTG -> TGTTGTTCTGA
# GTGTTTAGACG -> TGTTTAGACGA
# GTTAAACCCCC -> TTAAACCCCCC
# GTTAAAGTTAA -> TTAAAGTTAAG
# GTTAACACTCT -> TTAACACTCTT
# GTTAAGGCCCC -> TTAAGGCCCCC
# GTTACCCGTAT -> TTACCCGTATA
# GTTACTATCCC -> TTACTATCCCC
# GTTATATTTCT -> TTATATTTCTC
# GTTATCAGACC -> TTATCAGACCG
# GTTATCGTGCC -> TTATCGTGCCT
# GTTATGTGCGA -> TTATGTGCGAC
# GTTCCCTGGCA -> TTCCCTGGCAA
# GTTCCGGACTA -> TTCCGGACTAA
# GTTCCTAGTGT -> TTCCTAGTGTG
# GTTCGGGAACC -> TTCGGGAACCT
# GTTCTGATGGT -> TTCTGATGGTT
# GTTCTGCCGGA -> TTCTGCCGGAA
# GTTGAAATACA -> TTGAAATACAT
# GTTGATTCACG -> TTGATTCACGA
# GTTGCATTAAT -> TTGCATTAATA
# GTTGCGTATAG -> TTGCGTATAGT
# GTTGGCCTTGT -> TTGGCCTTGTT
# GTTGGGCCACA -> TTGGGCCACAG
# GTTGGGGGCGG -> TTGGGGGCGGC
# GTTGTTCTGAT -> TTGTTCTGATG
# GTTGTTGGCCT -> TTGTTGGCCTT
# GTTTACACCAG -> TTTACACCAGT
# GTTTACATCAA -> TTTACATCAAA
# GTTTAGACGAG -> TTTAGACGAGG
# GTTTCAATTGC -> TTTCAATTGCC
# GTTTCACTCGG -> TTTCACTCGGC
# GTTTCCGCGTA -> TTTCCGCGTAA
# GTTTGTTGCGT -> TTTGTTGCGTA
# GTTTTCGAGTT -> TTTTCGAGTTA
# GTTTTGGGGGA -> TTTTGGGGGAG
# TAAAAAAGTCT -> AAAAAAGTCTA
# TAAAACAACCC -> AAAACAACCCA
# TAAAACGGGCC -> AAAACGGGCCT
# TAAACCCCCCT -> AAACCCCCCTC
# TAAAGTTAAGG -> AAAGTTAAGGC
# TAAATACGCAT -> AAATACGCATC
# TAAATGGCTTC -> AAATGGCTTCG
# TAACAAAATAC -> AACAAAATACT
# TAACACTCTTA -> AACACTCTTAT
# TAACAGCAATG -> AACAGCAATGA
# TAACCCGCGCC -> AACCCGCGCCG
# TAACCCTGTGC -> AACCCTGTGCG
# TAACCGTTCTG -> AACCGTTCTGC
# TAACCTGTAAC -> AACCTGTAACG
# TAACGAGACAG -> AACGAGACAGT
# TAACGGCGTCC -> AACGGCGTCCC
# TAACTGACGTC -> AACTGACGTCG
# TAACTGGCGAG -> AACTGGCGAGG
# TAAGAACACTA -> AAGAACACTAT
# TAAGGAGTGAG -> AAGGAGTGAGA
# TAAGGATCGAG -> AAGGATCGAGC
# TAAGGATTGTT -> AAGGATTGTTT
# TAAGGCCCCCT -> AAGGCCCCCTC
# TAAGTGTTGTT -> AAGTGTTGTTC
# TAATAGACCGT -> AATAGACCGTA
# TAATATAACGG -> AATATAACGGC
# TAATATGCCCG -> AATATGCCCGC
# TAATCAAATCC -> AATCAAATCCA
# TAATCTGGTTA -> AATCTGGTTAA
# TAATGATTAGT -> AATGATTAGTT
# TAATGGCTATC -> AATGGCTATCA
# TAATGTACAAG -> AATGTACAAGG
# TAATTCACACA -> AATTCACACAC
# TAATTCTCTTC -> AATTCTCTTCG
# TACAAGGTATA -> ACAAGGTATAA
# TACACATGGCG -> ACACATGGCGG
# TACACCAGTAC -> ACACCAGTACA
# TACACCGATGC -> ACACCGATGCC
# TACACTCAGAG -> ACACTCAGAGT
# TACACTCGCCG -> ACACTCGCCGT
# TACATATTCGC -> ACATATTCGCA
# TACATCAAATT -> ACATCAAATTT
# TACATCGCGGA -> ACATCGCGGAG
# TACATGGTACA -> ACATGGTACAC
# TACCAACATCA -> ACCAACATCAT
# TACCCCGCTAA -> ACCCCGCTAAT
# TACCCCTCGCG -> ACCCCTCGCGA
# TACCCGATCAC -> ACCCGATCACC
# TACCCGTATAA -> ACCCGTATAAT
# TACCGGGGCGC -> ACCGGGGCGCT
# TACCTAGAAGT -> ACCTAGAAGTA
# TACCTGATCTG -> ACCTGATCTGT
# TACGAATATGC -> ACGAATATGCT
# TACGATTTTGA -> ACGATTTTGAG
# TACGCATCTCG -> ACGCATCTCGA
# TACGTCACTCA -> ACGTCACTCAC
# TACTAGTCCGA -> ACTAGTCCGAC
# TACTATCCCCG -> ACTATCCCCGA
# TACTCAGGATC -> ACTCAGGATCG
# TACTCGTGTCG -> ACTCGTGTCGC
# TACTCTTGGCG -> ACTCTTGGCGC
# TACTGACCACG -> ACTGACCACGA
# TACTGCTCGTC -> ACTGCTCGTCA
# TAGAAGTATAC -> AGAAGTATACA
# TAGACCGTACT -> AGACCGTACTC
# TAGACGAGGGG -> AGACGAGGGGT
# TAGACTCATAT -> AGACTCATATT
# TAGAGACAGTC -> AGAGACAGTCA
# TAGAGCGCCAA -> AGAGCGCCAAT
# TAGAGGACTCC -> AGAGGACTCCG
# TAGCACCGGTT -> AGCACCGGTTA
# TAGCGAGTTGT -> AGCGAGTTGTT
# TAGGACAAAGA -> AGGACAAAGAT
# TAGGACCCCAG -> AGGACCCCAGT
# TAGGAGGCAGT -> AGGAGGCAGTC
# TAGGAGGGCCA -> AGGAGGGCCAC
# TAGGCAGAGGA -> AGGCAGAGGAA
# TAGGCGTATTA -> AGGCGTATTAG
# TAGGGCTTGGT -> AGGGCTTGGTC
# TAGGTTTACAT -> AGGTTTACATC
# TAGTCAGGTAG -> AGTCAGGTAGT
# TAGTCCGACCA -> AGTCCGACCAT
# TAGTGACCGGG -> AGTGACCGGGA
# TAGTGTATCGC -> AGTGTATCGCT
# TAGTGTGTAAC -> AGTGTGTAACT
# TAGTTGCATTA -> AGTTGCATTAA
# TAGTTGGGGGC -> AGTTGGGGGCG
# TATAACCGTTC -> ATAACCGTTCT
# TATAACGGCGT -> ATAACGGCGTC
# TATAATATAAC -> ATAATATAACG
# TATAATGTACA -> ATAATGTACAA
# TATAATTCACA -> ATAATTCACAC
# TATACATATTC -> ATACATATTCG
# TATACGAATAT -> ATACGAATATG
# TATACTGACCA -> ATACTGACCAC
# TATAGTCAGGT -> ATAGTCAGGTA
# TATATAATATA -> ATATAATATAA
# TATATGTTATG -> ATATGTTATGT
# TATATTTCTCC -> ATATTTCTCCG
# TATCAAGTCCA -> ATCAAGTCCAC
# TATCACAATAG -> ATCACAATAGC
# TATCAGACCGC -> ATCAGACCGCT
# TATCATCAGTC -> ATCATCAGTCT
# TATCCCCGAAA -> ATCCCCGAAAC
# TATCGAGGCCT -> ATCGAGGCCTC
# TATCGCTCGGT -> ATCGCTCGGTA
# TATCGGCAGGA -> ATCGGCAGGAT
# TATCGTGCCTT -> ATCGTGCCTTG
# TATCTCCGATT -> ATCTCCGATTA
# TATGACTGTAA -> ATGACTGTAAA
# TATGAGTTATC -> ATGAGTTATCA
# TATGCAAGACT -> ATGCAAGACTG
# TATGCCCGCAG -> ATGCCCGCAGG
# TATGCCGCGAT -> ATGCCGCGATA
# TATGCTTTGTC -> ATGCTTTGTCC
# TATGGGGCACA -> ATGGGGCACAA
# TATGTGCGACC -> ATGTGCGACCA
# TATGTTATGTG -> ATGTTATGTGC
# TATTAATGGCT -> ATTAATGGCTA
# TATTACCTAGA -> ATTACCTAGAA
# TATTACTAGTC -> ATTACTAGTCC
# TATTAGGAGGG -> ATTAGGAGGGC
# TATTCCATCAT -> ATTCCATCATG
# TATTCCATGGC -> ATTCCATGGCA
# TATTCGCACAC -> ATTCGCACACC
# TATTGCCCCCG -> ATTGCCCCCGT
# TATTTCTCCGA -> ATTTCTCCGAA
# TCAAACCAACG -> CAAACCAACGC
# TCAAAGGTCAT -> CAAAGGTCATC
# TCAAATCCAAT -> CAAATCCAATG
# TCAAATTTGGC -> CAAATTTGGCG
# TCAACGTAATT -> CAACGTAATTC
# TCAAGAGCCGC -> CAAGAGCCGCT
# TCAAGCCTGCT -> CAAGCCTGCTA
# TCAAGGCAACT -> CAAGGCAACTT
# TCAAGGCCCGT -> CAAGGCCCGTA
# TCAAGTCCACT -> CAAGTCCACTA
# TCAATCAAGGC -> CAATCAAGGCA
# TCAATTGCCAG -> CAATTGCCAGG
# TCACAATAGCG -> CACAATAGCGA
# TCACACACGTT -> CACACACGTTC
# TCACAGACTGT -> CACAGACTGTG
# TCACCGCCGGA -> CACCGCCGGAA
# TCACCTAGAGG -> CACCTAGAGGA
# TCACGACAAGG -> CACGACAAGGC
# TCACTACCAAC -> CACTACCAACA
# TCACTCACCTA -> CACTCACCTAG
# TCACTCGGCAA -> CACTCGGCAAA
# TCAGAATGCGG -> CAGAATGCGGC
# TCAGACCGCTT -> CAGACCGCTTT
# TCAGAGGGCTT -> CAGAGGGCTTG
# TCAGAGTATTA -> CAGAGTATTAC
# TCAGCGCAAGA -> CAGCGCAAGAT
# TCAGGATCGCC -> CAGGATCGCCA
# TCAGGCTAAGA -> CAGGCTAAGAA
# TCAGGTAGTTG -> CAGGTAGTTGG
# TCAGTCTTATT -> CAGTCTTATTA
# TCATATTAATG -> CATATTAATGG
# TCATCAGGCTA -> CATCAGGCTAA
# TCATCAGTCTT -> CATCAGTCTTA
# TCATGATTATT -> CATGATTATTC
# TCATGCTGGGG -> CATGCTGGGGC
# TCATGGATCAA -> CATGGATCAAG
# TCATGTTATAT -> CATGTTATATT
# TCATTAATCAA -> CATTAATCAAA
# TCATTACTCGT -> CATTACTCGTG
# TCATTATGACT -> CATTATGACTG
# TCATTCCGCCA -> CATTCCGCCAA
# TCATTCGGTTC -> CATTCGGTTCC
# TCCAATGTAGA -> CCAATGTAGAG
# TCCACGATCGA -> CCACGATCGAA
# TCCACTAAAAC -> CCACTAAAACG
# TCCACTCAAAG -> CCACTCAAAGG
# TCCATATTGCC -> CCATATTGCCC
# TCCATCATGAT -> CCATCATGATT
# TCCATGGCAAG -> CCATGGCAAGA
# TCCCCGAAACA -> CCCCGAAACAG
# TCCCTGACCGA -> CCCTGACCGAT
# TCCCTGGCAAC -> CCCTGGCAACA
# TCCCTTAGGCA -> CCCTTAGGCAG
# TCCGAAGGGCT -> CCGAAGGGCTG
# TCCGACCATGC -> CCGACCATGCG
# TCCGATGAGGC -> CCGATGAGGCT
# TCCGATTAGGA -> CCGATTAGGAC
# TCCGCCAATCC -> CCGCCAATCCT
# TCCGCCTGAGC -> CCGCCTGAGCT
# TCCGCGTAACC -> CCGCGTAACCT
# TCCGGAAAGTT -> CCGGAAAGTTC
# TCCGGACTAAC -> CCGGACTAACC
# TCCGTGTCATT -> CCGTGTCATTA
# TCCTAGTGTGT -> CCTAGTGTGTA
# TCCTCGAAGTG -> CCTCGAAGTGT
# TCCTGCTTATC -> CCTGCTTATCA
# TCCTTATACGA -> CCTTATACGAA
# TCGAAAACCAT -> CGAAAACCATG
# TCGAAGTGTTT -> CGAAGTGTTTA
# TCGACATCGGC -> CGACATCGGCT
# TCGAGAAGTCG -> CGAGAAGTCGT
# TCGAGCACAAG -> CGAGCACAAGA
# TCGAGGCCTCT -> CGAGGCCTCTT
# TCGAGTTATCG -> CGAGTTATCGT
# TCGATCTTATC -> CGATCTTATCG
# TCGCACACCTG -> CGCACACCTGT
# TCGCCAATCAT -> CGCCAATCATT
# TCGCCGCTATC -> CGCCGCTATCA
# TCGCCGTGCCA -> CGCCGTGCCAA
# TCGCGAAACGC -> CGCGAAACGCC
# TCGCGCGCGGT -> CGCGCGCGGTT
# TCGCGGAGTGT -> CGCGGAGTGTG
# TCGCTCGGTAA -> CGCTCGGTAAG
# TCGGATCGCCG -> CGGATCGCCGC
# TCGGCAAATAC -> CGGCAAATACA
# TCGGCAGGATT -> CGGCAGGATTC
# TCGGCTCTCCG -> CGGCTCTCCGG
# TCGGGAACCTC -> CGGGAACCTCT
# TCGGTAAGTGT -> CGGTAAGTGTT
# TCGGTCCACGA -> CGGTCCACGAT
# TCGGTTCCGGA -> CGGTTCCGGAC
# TCGTACGATTT -> CGTACGATTTT
# TCGTCAGCGCA -> CGTCAGCGCAA
# TCGTGCCTTGG -> CGTGCCTTGGT
# TCGTGGTTTTC -> CGTGGTTTTCG
# TCGTGTCGCAT -> CGTGTCGCATA
# TCGTTACTATC -> CGTTACTATCC
# TCGTTTACACC -> CGTTTACACCA
# TCGTTTTGGGG -> CGTTTTGGGGG
# TCTAAAAAAGT -> CTAAAAAAGTC
# TCTAAGGAGTG -> CTAAGGAGTGA
# TCTAAGGATCG -> CTAAGGATCGA
# TCTACCCCTCG -> CTACCCCTCGC
# TCTAGGGCTTG -> CTAGGGCTTGG
# TCTATGCAAGA -> CTATGCAAGAC
# TCTCCGAAGGG -> CTCCGAAGGGC
# TCTCCGATTAG -> CTCCGATTAGG
# TCTCCGGAAAG -> CTCCGGAAAGT
# TCTCGATCTTA -> CTCGATCTTAT
# TCTCTTCGAGA -> CTCTTCGAGAA
# TCTGAAATAAC -> CTGAAATAACA
# TCTGATCGGAT -> CTGATCGGATC
# TCTGATGGTTT -> CTGATGGTTTC
# TCTGCCGGAAT -> CTGCCGGAATT
# TCTGCTGAGTT -> CTGCTGAGTTG
# TCTGGTTAAAG -> CTGGTTAAAGT
# TCTGTATATGT -> CTGTATATGTT
# TCTGTGCCCTA -> CTGTGCCCTAT
# TCTGTTTGTTG -> CTGTTTGTTGC
# TCTTATAATGT -> CTTATAATGTA
# TCTTATCGAGG -> CTTATCGAGGC
# TCTTATTACTA -> CTTATTACTAG
# TCTTCGAGAAG -> CTTCGAGAAGT
# TCTTGGCGCAT -> CTTGGCGCATG
# TCTTTACCCCG -> CTTTACCCCGC
# TGAAACCTCTG -> GAAACCTCTGA
# TGAAATAACAG -> GAAATAACAGC
# TGAAATACATG -> GAAATACATGG
# TGAACCGGCTA -> GAACCGGCTAT
# TGAAGGCTCAG -> GAAGGCTCAGA
# TGACCACGAGA -> GACCACGAGAG
# TGACCGATTAC -> GACCGATTACG
# TGACCGGGAAT -> GACCGGGAATC
# TGACGGCCCTC -> GACGGCCCTCA
# TGACGGTGTTA -> GACGGTGTTAA
# TGACGTCGGTC -> GACGTCGGTCC
# TGACTGTAAAA -> GACTGTAAAAC
# TGAGACACCTA -> GAGACACCTAA
# TGAGATCCTTA -> GAGATCCTTAT
# TGAGCTATGCC -> GAGCTATGCCG
# TGAGGCTAGTG -> GAGGCTAGTGA
# TGAGGCTATTC -> GAGGCTATTCC
# TGAGGCTCGTG -> GAGGCTCGTGG
# TGAGTTATCAG -> GAGTTATCAGA
# TGAGTTGAAAT -> GAGTTGAAATA
# TGATCGGATCG -> GATCGGATCGC
# TGATCTGTGCC -> GATCTGTGCCC
# TGATCTGTTTG -> GATCTGTTTGT
# TGATGCATCAG -> GATGCATCAGA
# TGATGGTTTCA -> GATGGTTTCAC
# TGATGTCACAG -> GATGTCACAGA
# TGATTAGTTGC -> GATTAGTTGCA
# TGATTATTCCA -> GATTATTCCAT
# TGATTCACGAC -> GATTCACGACA
# TGCAACTACCC -> GCAACTACCCG
# TGCAAGACTGA -> GCAAGACTGAT
# TGCATCAGAGG -> GCATCAGAGGG
# TGCATTAATAG -> GCATTAATAGA
# TGCCAACTAAG -> GCCAACTAAGG
# TGCCAGGATTT -> GCCAGGATTTT
# TGCCATTGAAG -> GCCATTGAAGG
# TGCCCCCGTCT -> GCCCCCGTCTA
# TGCCCGCAGGC -> GCCCGCAGGCA
# TGCCCTATACT -> GCCCTATACTG
# TGCCGCGATAA -> GCCGCGATAAA
# TGCCGCGCTGC -> GCCGCGCTGCC
# TGCCGGAATTG -> GCCGGAATTGT
# TGCCTGTGGCT -> GCCTGTGGCTT
# TGCCTTGGTCG -> GCCTTGGTCGT
# TGCGACCACAG -> GCGACCACAGC
# TGCGAGGCAAT -> GCGAGGCAATT
# TGCGCCTGGTG -> GCGCCTGGTGA
# TGCGGCTTTGC -> GCGGCTTTGCT
# TGCGGGTCTGT -> GCGGGTCTGTA
# TGCGTACCTGA -> GCGTACCTGAT
# TGCGTATAGTC -> GCGTATAGTCA
# TGCTACTCTTG -> GCTACTCTTGG
# TGCTAGGACCC -> GCTAGGACCCC
# TGCTAGGAGGC -> GCTAGGAGGCA
# TGCTCCCTTAG -> GCTCCCTTAGG
# TGCTCGTCAGC -> GCTCGTCAGCG
# TGCTGAGTTGA -> GCTGAGTTGAA
# TGCTGGGGCAA -> GCTGGGGCAAC
# TGCTTATCATC -> GCTTATCATCA
# TGCTTTGTCCG -> GCTTTGTCCGT
# TGGATCAAGGC -> GGATCAAGGCC
# TGGCAACATCT -> GGCAACATCTA
# TGGCAAGATAA -> GGCAAGATAAT
# TGGCCTCACTA -> GGCCTCACTAC
# TGGCCTTGTTT -> GGCCTTGTTTC
# TGGCGAGGCAG -> GGCGAGGCAGA
# TGGCGCATGTG -> GGCGCATGTGA
# TGGCGCTACAC -> GGCGCTACACT
# TGGCGGGTTGA -> GGCGGGTTGAT
# TGGCTATCACA -> GGCTATCACAA
# TGGCTTCGCGC -> GGCTTCGCGCG
# TGGCTTGGGGC -> GGCTTGGGGCT
# TGGGCACAGCG -> GGGCACAGCGA
# TGGGCCACAGA -> GGGCCACAGAA
# TGGGGCAACAC -> GGGGCAACACA
# TGGGGCACAAC -> GGGGCACAACA
# TGGGGCTGGGC -> GGGGCTGGGCA
# TGGGGGAGAAG -> GGGGGAGAAGC
# TGGGGGCGGCA -> GGGGGCGGCAG
# TGGTACACCGA -> GGTACACCGAT
# TGGTAGACTCA -> GGTAGACTCAT
# TGGTCCTGCTT -> GGTCCTGCTTA
# TGGTCGTACGA -> GGTCGTACGAT
# TGGTCTGAAAT -> GGTCTGAAATA
# TGGTGAGGCTC -> GGTGAGGCTCG
# TGGTGCAACTA -> GGTGCAACTAC
# TGGTTAAAGTT -> GGTTAAAGTTA
# TGGTTGGGCCA -> GGTTGGGCCAC
# TGGTTTCACTC -> GGTTTCACTCG
# TGGTTTTCGAG -> GGTTTTCGAGT
# TGTAAAACAAC -> GTAAAACAACC
# TGTAACGAGAC -> GTAACGAGACA
# TGTAACTGACG -> GTAACTGACGT
# TGTACAAGGTA -> GTACAAGGTAT
# TGTAGAGCGCC -> GTAGAGCGCCA
# TGTAGGCGTAT -> GTAGGCGTATT
# TGTATATGTTA -> GTATATGTTAT
# TGTATCGCTCG -> GTATCGCTCGG
# TGTATCGGCAG -> GTATCGGCAGG
# TGTCACAGACT -> GTCACAGACTG
# TGTCATTACTC -> GTCATTACTCG
# TGTCCGTGTCA -> GTCCGTGTCAT
# TGTCGCATACA -> GTCGCATACAA
# TGTCTAAAAAA -> GTCTAAAAAAG
# TGTGAACCGGC -> GTGAACCGGCT
# TGTGACGGCCC -> GTGACGGCCCT
# TGTGCCCTATA -> GTGCCCTATAC
# TGTGCCGCGCT -> GTGCCGCGCTG
# TGTGCGACCAC -> GTGCGACCACA
# TGTGCGCCTGG -> GTGCGCCTGGT
# TGTGCGGGTCT -> GTGCGGGTCTG
# TGTGCTCCCTT -> GTGCTCCCTTA
# TGTGGCTTGGG -> GTGGCTTGGGG
# TGTGTAACTGA -> GTGTAACTGAC
# TGTGTCTAAAA -> GTGTCTAAAAA
# TGTTAACACTC -> GTTAACACTCT
# TGTTATATTTC -> GTTATATTTCT
# TGTTATGTGCG -> GTTATGTGCGA
# TGTTCTGATGG -> GTTCTGATGGT
# TGTTGCGTATA -> GTTGCGTATAG
# TGTTGGCCTTG -> GTTGGCCTTGT
# TGTTGTTCTGA -> GTTGTTCTGAT
# TGTTTAGACGA -> GTTTAGACGAG
# TGTTTCAATTG -> GTTTCAATTGC
# TGTTTCCGCGT -> GTTTCCGCGTA
# TGTTTGTTGCG -> GTTTGTTGCGT
# TTAAACCCCCC -> TAAACCCCCCT
# TTAAAGTTAAG -> TAAAGTTAAGG
# TTAACAAAATA -> TAACAAAATAC
# TTAACACTCTT -> TAACACTCTTA
# TTAAGGCCCCC -> TAAGGCCCCCT
# TTAATAGACCG -> TAATAGACCGT
# TTAATCAAATC -> TAATCAAATCC
# TTAATGGCTAT -> TAATGGCTATC
# TTACACCAGTA -> TACACCAGTAC
# TTACATCAAAT -> TACATCAAATT
# TTACCCCGCTA -> TACCCCGCTAA
# TTACCCGTATA -> TACCCGTATAA
# TTACCTAGAAG -> TACCTAGAAGT
# TTACGTCACTC -> TACGTCACTCA
# TTACTAGTCCG -> TACTAGTCCGA
# TTACTATCCCC -> TACTATCCCCG
# TTACTCGTGTC -> TACTCGTGTCG
# TTAGACGAGGG -> TAGACGAGGGG
# TTAGAGACAGT -> TAGAGACAGTC
# TTAGGACAAAG -> TAGGACAAAGA
# TTAGGAGGGCC -> TAGGAGGGCCA
# TTAGGCAGAGG -> TAGGCAGAGGA
# TTAGTTGCATT -> TAGTTGCATTA
# TTATAATGTAC -> TATAATGTACA
# TTATACGAATA -> TATACGAATAT
# TTATATTTCTC -> TATATTTCTCC
# TTATCAGACCG -> TATCAGACCGC
# TTATCATCAGT -> TATCATCAGTC
# TTATCGAGGCC -> TATCGAGGCCT
# TTATCGTGCCT -> TATCGTGCCTT
# TTATGACTGTA -> TATGACTGTAA
# TTATGTGCGAC -> TATGTGCGACC
# TTATTACTAGT -> TATTACTAGTC
# TTATTCCATGG -> TATTCCATGGC
# TTCAAGAGCCG -> TCAAGAGCCGC
# TTCAAGCCTGC -> TCAAGCCTGCT
# TTCAATTGCCA -> TCAATTGCCAG
# TTCACACACGT -> TCACACACGTT
# TTCACGACAAG -> TCACGACAAGG
# TTCACTCGGCA -> TCACTCGGCAA
# TTCATGGATCA -> TCATGGATCAA
# TTCCATCATGA -> TCCATCATGAT
# TTCCATGGCAA -> TCCATGGCAAG
# TTCCCTGGCAA -> TCCCTGGCAAC
# TTCCGCCAATC -> TCCGCCAATCC
# TTCCGCCTGAG -> TCCGCCTGAGC
# TTCCGCGTAAC -> TCCGCGTAACC
# TTCCGGACTAA -> TCCGGACTAAC
# TTCCTAGTGTG -> TCCTAGTGTGT
# TTCGAGAAGTC -> TCGAGAAGTCG
# TTCGAGTTATC -> TCGAGTTATCG
# TTCGCACACCT -> TCGCACACCTG
# TTCGCGCGCGG -> TCGCGCGCGGT
# TTCGGGAACCT -> TCGGGAACCTC
# TTCGGTTCCGG -> TCGGTTCCGGA
# TTCTAGGGCTT -> TCTAGGGCTTG
# TTCTCCGAAGG -> TCTCCGAAGGG
# TTCTCTTCGAG -> TCTCTTCGAGA
# TTCTGATGGTT -> TCTGATGGTTT
# TTCTGCCGGAA -> TCTGCCGGAAT
# TTGAAATACAT -> TGAAATACATG
# TTGAAGGCTCA -> TGAAGGCTCAG
# TTGAGGCTATT -> TGAGGCTATTC
# TTGATTCACGA -> TGATTCACGAC
# TTGCATTAATA -> TGCATTAATAG
# TTGCCAGGATT -> TGCCAGGATTT
# TTGCCCCCGTC -> TGCCCCCGTCT
# TTGCGTATAGT -> TGCGTATAGTC
# TTGCTACTCTT -> TGCTACTCTTG
# TTGGCCTCACT -> TGGCCTCACTA
# TTGGCCTTGTT -> TGGCCTTGTTT
# TTGGCGCATGT -> TGGCGCATGTG
# TTGGCGCTACA -> TGGCGCTACAC
# TTGGGCCACAG -> TGGGCCACAGA
# TTGGGGCTGGG -> TGGGGCTGGGC
# TTGGGGGAGAA -> TGGGGGAGAAG
# TTGGGGGCGGC -> TGGGGGCGGCA
# TTGGTCCTGCT -> TGGTCCTGCTT
# TTGGTCGTACG -> TGGTCGTACGA
# TTGGTCTGAAA -> TGGTCTGAAAT
# TTGTATCGGCA -> TGTATCGGCAG
# TTGTCCGTGTC -> TGTCCGTGTCA
# TTGTGCGCCTG -> TGTGCGCCTGG
# TTGTTCTGATG -> TGTTCTGATGG
# TTGTTGCGTAT -> TGTTGCGTATA
# TTGTTGGCCTT -> TGTTGGCCTTG
# TTGTTTCAATT -> TGTTTCAATTG
# TTGTTTCCGCG -> TGTTTCCGCGT
# TTTACACCAGT -> TTACACCAGTA
# TTTACATCAAA -> TTACATCAAAT
# TTTACCCCGCT -> TTACCCCGCTA
# TTTAGACGAGG -> TTAGACGAGGG
# TTTAGAGACAG -> TTAGAGACAGT
# TTTCAAGCCTG -> TTCAAGCCTGC
# TTTCAATTGCC -> TTCAATTGCCA
# TTTCACTCGGC -> TTCACTCGGCA
# TTTCATGGATC -> TTCATGGATCA
# TTTCCGCGTAA -> TTCCGCGTAAC
# TTTCGAGTTAT -> TTCGAGTTATC
# TTTCTAGGGCT -> TTCTAGGGCTT
# TTTCTCCGAAG -> TTCTCCGAAGG
# TTTGAGGCTAT -> TTGAGGCTATT
# TTTGCTACTCT -> TTGCTACTCTT
# TTTGGCGCTAC -> TTGGCGCTACA
# TTTGGGGGAGA -> TTGGGGGAGAA
# TTTGTCCGTGT -> TTGTCCGTGTC
# TTTGTTGCGTA -> TTGTTGCGTAT
# TTTTCAAGCCT -> TTTCAAGCCTG
# TTTTCGAGTTA -> TTTCGAGTTAT
# TTTTCTAGGGC -> TTTCTAGGGCT
# TTTTGAGGCTA -> TTTGAGGCTAT
# TTTTGGGGGAG -> TTTGGGGGAGA

# %% [markdown]
# # Inspection:
# #### Inspector 1:
#         Reduce the size of your main function
#         Save more into self variables
#         Clean up your code overall so it's readable
# #### Inspector 2:
#         Write a few more comments to further describe your code
# #### Inspector 3:
#         Try to write the sorted dictionary in another method rather than in main
#         Try to write your code in a more compact fashion
